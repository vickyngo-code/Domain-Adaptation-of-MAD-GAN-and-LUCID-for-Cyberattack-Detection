# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "-1"

# %%
# !python3 RGAN.py --settings_file cicddos
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-DDoS/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-DDoS/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/cicddos.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded CICDDoS2017 from .csv
# (529918, 79)
# num_samples: 52988
# num_signals: 6
# Generated/loaded 52988 samples from data-type cicddos2017
# samples_size: (52988, 30, 6)
# num_variables: 6
# Ready to run with settings:
#  	 settings_file
# cicddos2017 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# 1 	 kappa
# 15 	 latent_dim
# 0.5 	 weight
# 1 	 degree
# False 	 batch_mean
# False 	 learn_scale
# 0.1 	 learning_rate
# 500 	 batch_size
# 100 	 num_epochs
# 1 	 D_rounds
# 3 	 G_rounds
# 1 	 E_rounds
# True 	 shuffle
# False 	 eval_mul
# False 	 eval_an
# False 	 eval_single
# False 	 wrong_labels
# swat 	 identifier
# cicddos 	 sub_id
# False 	 dp
# 1e-05 	 l2norm_bound
# 1 	 batches_per_lot
# 1e-05 	 dp_sigma
# False 	 use_time
# 10 	 seq_step
# 6 	 num_generated_features
# 2022-11-18 14:03:54.786738: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2022-11-18 14:03:54.814579: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3499910000 Hz
# 2022-11-18 14:03:54.816604: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55591796da80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-11-18 14:03:54.816640: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-11-18 14:03:54.820197: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-11-18 14:03:54.846795: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-11-18 14:03:54.846846: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ws103a-z41387
# 2022-11-18 14:03:54.846861: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ws103a-z41387
# 2022-11-18 14:03:54.847016: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 520.61.5
# 2022-11-18 14:03:54.847061: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 520.61.5
# 2022-11-18 14:03:54.847074: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 520.61.5
# epoch, D_loss_curr, G_loss_curr, seq_length
# 0	0.0456	5.9203	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_0.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 1	0.3922	4.3772	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_1.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 2	0.0171	7.6755	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_2.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 3	0.0094	6.6575	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_3.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 4	0.0076	7.1949	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_4.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 5	0.0144	7.6620	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_5.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 6	0.0208	5.0277	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_6.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 7	0.0151	5.3971	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_7.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 8	0.0143	5.8038	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_8.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 9	0.0149	6.0932	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_9.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 10	0.0162	6.0969	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_10.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 11	0.0167	5.2475	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_11.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 12	0.0093	6.4815	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_12.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 13	0.0101	6.7116	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_13.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 14	0.0104	6.9256	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_14.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 15	0.0100	7.2562	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_15.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 16	0.0099	7.6198	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_16.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 17	0.0095	7.8953	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_17.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 18	0.0096	7.9825	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_18.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 19	0.0079	6.4548	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_19.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 20	0.0065	7.1670	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_20.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 21	0.0067	7.4971	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_21.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 22	0.0100	8.5293	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_22.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 23	0.0095	8.0327	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_23.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 24	0.0078	8.4638	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_24.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 25	0.0071	8.5498	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_25.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 26	0.0094	7.3142	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_26.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 27	0.0072	8.9578	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_27.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 28	0.0066	9.2640	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_28.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 29	0.0063	9.3508	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_29.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 30	0.0064	9.4485	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_30.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 31	0.0066	9.5576	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_31.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 32	0.0064	8.4593	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_32.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 33	0.0061	7.9894	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_33.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 34	0.0058	9.0272	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_34.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 35	0.0060	8.8895	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_35.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 36	0.0063	9.3520	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_36.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 37	0.0064	9.3356	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_37.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 38	0.0059	9.7693	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_38.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 39	0.0059	9.5876	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_39.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 40	0.0058	9.5689	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_40.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 41	0.0055	9.1076	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_41.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 42	0.0054	9.1375	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_42.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 43	0.0053	9.3154	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_43.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 44	0.0054	9.5888	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_44.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 45	0.0054	9.7393	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_45.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 46	0.0056	9.5696	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_46.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 47	0.0054	9.5333	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_47.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 48	0.0052	9.5497	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_48.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 49	0.0050	9.0549	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_49.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 50	0.0052	9.1196	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_50.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 51	0.0053	9.1749	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_51.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 52	0.0049	9.2761	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_52.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 53	0.0049	9.4873	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_53.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 54	0.0049	9.3750	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_54.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 55	0.0049	9.4266	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_55.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 56	0.0048	9.5238	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_56.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 57	0.0048	9.5570	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_57.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 58	0.0048	9.6328	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_58.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 59	0.0048	9.7095	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_59.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 60	0.0048	9.7630	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_60.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 61	0.0047	9.8077	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_61.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 62	0.0047	9.8438	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_62.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 63	0.0047	9.9244	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_63.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 64	0.0045	10.0116	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_64.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 65	0.0045	10.0327	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_65.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 66	0.0046	10.1144	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_66.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 67	0.0046	10.1373	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_67.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 68	0.0048	10.2028	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_68.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 69	0.0052	9.6698	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_69.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 70	0.0050	10.1707	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_70.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 71	0.0050	10.6874	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_71.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 72	0.0048	10.7395	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_72.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 73	0.0048	10.9215	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_73.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 74	0.0048	11.0588	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_74.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 75	0.0047	11.1957	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_75.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 76	0.0047	11.2801	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_76.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 77	0.0046	11.3704	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_77.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 78	0.0046	11.4678	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_78.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 79	0.0045	11.5243	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_79.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 80	0.0044	11.6266	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_80.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 81	0.0044	11.7188	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_81.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 82	0.0043	11.7266	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_82.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 83	0.0043	11.8424	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_83.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 84	0.0043	11.9234	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_84.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 85	0.0043	12.0378	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_85.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 86	0.0042	12.1084	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_86.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 87	0.0042	12.1184	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_87.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 88	0.0042	12.2172	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_88.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 89	0.0041	12.3002	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_89.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 90	0.0040	12.2880	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_90.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 91	0.0040	12.3739	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_91.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 92	0.0041	12.4596	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_92.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 93	0.0040	12.4927	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_93.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 94	0.0039	12.5930	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_94.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 95	0.0040	12.6549	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_95.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 96	0.0039	12.6794	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_96.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 97	0.0039	12.7705	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_97.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 98	0.0038	12.8843	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_98.npy
# epoch, D_loss_curr, G_loss_curr, seq_length
# 99	0.0038	12.9514	30
# Recorded 8 parameters to ./experiments/parameters/cicddos_30_99.npy
# Training terminated | Training time=1912 s
# Training terminated | training time = 1912s

# %%
# !python3 AD.py --settings_file cicddos_test
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-DDoS/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-DDoS/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/cicddos_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded CICDDoS2019 from .csv
# (388769, 79)
# Generated/loaded 38873 samples from data-type cicddos2019
# Ready to run with settings:
#  	 settings_file
# cicddos2019 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# 1 	 kappa
# 15 	 latent_dim
# 0.5 	 weight
# 1 	 degree
# False 	 batch_mean
# False 	 learn_scale
# 0.1 	 learning_rate
# 500 	 batch_size
# 100 	 num_epochs
# 1 	 D_rounds
# 3 	 G_rounds
# 1 	 E_rounds
# True 	 shuffle
# False 	 eval_mul
# False 	 eval_an
# False 	 eval_single
# False 	 wrong_labels
# swat_test 	 identifier
# cicddos 	 sub_id
# False 	 dp
# 1e-05 	 l2norm_bound
# 1 	 batches_per_lot
# 1e-05 	 dp_sigma
# False 	 use_time
# 10 	 seq_step
# 6 	 num_generated_features
# Main Starting...
# sample_shape: 38873
# num_samples_t 38873
# 2022-11-18 20:25:37.554801: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 AVX512F FMA
# 2022-11-18 20:25:37.582612: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 3499910000 Hz
# 2022-11-18 20:25:37.584039: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x558797b261c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2022-11-18 20:25:37.584080: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2022-11-18 20:25:37.587610: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2022-11-18 20:25:37.615141: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-11-18 20:25:37.615205: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: ws103a-z41387
# 2022-11-18 20:25:37.615223: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: ws103a-z41387
# 2022-11-18 20:25:37.615404: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 520.61.5
# 2022-11-18 20:25:37.615456: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 520.61.5
# 2022-11-18 20:25:37.615476: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 520.61.5
# N: 30753ch
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.2; Accu: 7.911; Pre: 0.9984; Rec: 0.07017; F1: 0.1311
# N: 96707
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.2; Accu: 24.88; Pre: 0.9997; Rec: 0.2415; F1: 0.389
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.2; Accu: 24.4; Pre: 1.0; Rec: 0.2426; F1: 0.3905
# N: 47142
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.3; Accu: 12.13; Pre: 0.998; Rec: 0.1129; F1: 0.2028
# N: 132251
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.3; Accu: 34.02; Pre: 0.9996; Rec: 0.3338; F1: 0.5005
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.3; Accu: 32.92; Pre: 1.0; Rec: 0.328; F1: 0.4939
# N: 61780
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.4; Accu: 15.89; Pre: 0.9976; Rec: 0.151; F1: 0.2623
# N: 158981
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.4; Accu: 40.9; Pre: 0.9996; Rec: 0.4033; F1: 0.5747
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.4; Accu: 39.45; Pre: 1.0; Rec: 0.3933; F1: 0.5646
# N: 77758
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.5; Accu: 20.0; Pre: 0.9973; Rec: 0.1927; F1: 0.323
# N: 190081
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.5; Accu: 48.9; Pre: 0.9994; Rec: 0.4842; F1: 0.6524
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.5; Accu: 48.31; Pre: 1.0; Rec: 0.4822; F1: 0.6506
# N: 94144
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.6; Accu: 24.22; Pre: 0.9971; Rec: 0.2354; F1: 0.3809
# N: 221204
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.6; Accu: 56.9; Pre: 0.999; Rec: 0.5654; F1: 0.7221
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.6; Accu: 56.29; Pre: 1.0; Rec: 0.5621; F1: 0.7197
# N: 111763
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.7; Accu: 28.75; Pre: 0.997; Rec: 0.2813; F1: 0.4388
# N: 267473
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.7; Accu: 68.8; Pre: 0.9981; Rec: 0.6863; F1: 0.8133
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.7; Accu: 68.4; Pre: 0.9998; Rec: 0.6835; F1: 0.812
# sample_shape: 38873
# num_samples_t 38873
# N: 37515ch
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.2; Accu: 9.65; Pre: 0.9992; Rec: 0.08769; F1: 0.1612
# N: 90603
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.2; Accu: 23.31; Pre: 0.9994; Rec: 0.2257; F1: 0.3682
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.2; Accu: 22.38; Pre: 1.0; Rec: 0.2224; F1: 0.3639
# N: 58934
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.3; Accu: 15.16; Pre: 0.999; Rec: 0.1434; F1: 0.2508
# N: 121716
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.3; Accu: 31.31; Pre: 0.9993; Rec: 0.3066; F1: 0.4692
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.3; Accu: 30.23; Pre: 1.0; Rec: 0.301; F1: 0.4627
# N: 79537
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.4; Accu: 20.46; Pre: 0.9989; Rec: 0.197; F1: 0.3291
# N: 143295
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.4; Accu: 36.86; Pre: 0.9992; Rec: 0.3627; F1: 0.5322
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.4; Accu: 35.85; Pre: 1.0; Rec: 0.3573; F1: 0.5265
# N: 93117
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.5; Accu: 23.95; Pre: 0.9987; Rec: 0.2324; F1: 0.377
# N: 189348
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.5; Accu: 48.71; Pre: 0.9993; Rec: 0.4824; F1: 0.6507
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.5; Accu: 47.82; Pre: 1.0; Rec: 0.4772; F1: 0.6461
# N: 105983
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.6; Accu: 27.26; Pre: 0.9985; Rec: 0.2659; F1: 0.4199
# N: 224262
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.6; Accu: 57.69; Pre: 0.9991; Rec: 0.5733; F1: 0.7285
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.6; Accu: 57.2; Pre: 1.0; Rec: 0.5712; F1: 0.7271
# N: 119604
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.7; Accu: 30.77; Pre: 0.9981; Rec: 0.3014; F1: 0.463
# N: 261771
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.7; Accu: 67.34; Pre: 0.9981; Rec: 0.6715; F1: 0.8028
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.7; Accu: 67.02; Pre: 1.0; Rec: 0.6696; F1: 0.8021
# sample_shape: 38873
# num_samples_t 38873
# N: 39760ch
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.2; Accu: 10.23; Pre: 0.9893; Rec: 0.09447; F1: 0.1725
# N: 76717
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.2; Accu: 19.73; Pre: 0.9997; Rec: 0.1895; F1: 0.3186
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.2; Accu: 18.18; Pre: 1.0; Rec: 0.1803; F1: 0.3056
# N: 56949
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.3; Accu: 14.65; Pre: 0.9762; Rec: 0.1416; F1: 0.2473
# N: 123890
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.3; Accu: 31.87; Pre: 0.9997; Rec: 0.3121; F1: 0.4757
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.3; Accu: 30.33; Pre: 1.0; Rec: 0.302; F1: 0.4639
# N: 74160
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.4; Accu: 19.08; Pre: 0.977; Rec: 0.1872; F1: 0.3142
# N: 163916
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.4; Accu: 42.16; Pre: 0.9995; Rec: 0.4162; F1: 0.5877
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.4; Accu: 41.02; Pre: 1.0; Rec: 0.4091; F1: 0.5806
# N: 90420
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.5; Accu: 23.26; Pre: 0.9798; Rec: 0.2298; F1: 0.3723
# N: 207338
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.5; Accu: 53.33; Pre: 0.9982; Rec: 0.5297; F1: 0.6921
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.5; Accu: 53.27; Pre: 1.0; Rec: 0.5318; F1: 0.6944
# N: 106688
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.6; Accu: 27.44; Pre: 0.9824; Rec: 0.2722; F1: 0.4263
# N: 241108
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.6; Accu: 62.02; Pre: 0.9924; Rec: 0.6212; F1: 0.7641
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.6; Accu: 61.46; Pre: 0.9977; Rec: 0.6153; F1: 0.7612
# N: 124351
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.7; Accu: 31.99; Pre: 0.9844; Rec: 0.3182; F1: 0.481
# N: 277926
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.7; Accu: 71.49; Pre: 0.9925; Rec: 0.7175; F1: 0.8329
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.7; Accu: 71.28; Pre: 0.998; Rec: 0.7137; F1: 0.8323
# sample_shape: 38873
# num_samples_t 38873
# N: 28109ch
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.2; Accu: 7.231; Pre: 0.9793; Rec: 0.06455; F1: 0.1211
# N: 82331
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.2; Accu: 21.18; Pre: 0.9804; Rec: 0.2082; F1: 0.3435
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.2; Accu: 20.32; Pre: 0.9932; Rec: 0.2031; F1: 0.3373
# N: 44934
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.3; Accu: 11.56; Pre: 0.9825; Rec: 0.1088; F1: 0.196
# N: 123327
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.3; Accu: 31.72; Pre: 0.985; Rec: 0.3153; F1: 0.4777
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.3; Accu: 31.24; Pre: 0.9956; Rec: 0.3125; F1: 0.4756
# N: 62897
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.4; Accu: 16.18; Pre: 0.9837; Rec: 0.1561; F1: 0.2695
# N: 175477
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.4; Accu: 45.14; Pre: 0.9853; Rec: 0.4528; F1: 0.6204
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.4; Accu: 46.49; Pre: 0.997; Rec: 0.4653; F1: 0.6345
# N: 83916
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.5; Accu: 21.59; Pre: 0.9845; Rec: 0.2115; F1: 0.3482
# N: 212393
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.5; Accu: 54.63; Pre: 0.9859; Rec: 0.5497; F1: 0.7059
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.5; Accu: 56.0; Pre: 0.9974; Rec: 0.5607; F1: 0.7178
# N: 106839
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.6; Accu: 27.48; Pre: 0.9855; Rec: 0.2717; F1: 0.426
# N: 244368
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.6; Accu: 62.86; Pre: 0.9854; Rec: 0.6344; F1: 0.7718
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.6; Accu: 64.33; Pre: 0.9972; Rec: 0.6444; F1: 0.7829
# N: 127897
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.7; Accu: 32.9; Pre: 0.9866; Rec: 0.3268; F1: 0.491
# N: 275460
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.7; Accu: 70.86; Pre: 0.9865; Rec: 0.7155; F1: 0.8294
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.7; Accu: 71.97; Pre: 0.9974; Rec: 0.721; F1: 0.837
# sample_shape: 38873
# num_samples_t 38873
# N: 26562ch
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.2; Accu: 6.833; Pre: 0.9856; Rec: 0.06005; F1: 0.1132
# N: 72817
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.2; Accu: 18.73; Pre: 0.9689; Rec: 0.1853; F1: 0.3111
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.2; Accu: 18.92; Pre: 0.991; Rec: 0.1894; F1: 0.3181
# N: 51801
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.3; Accu: 13.33; Pre: 0.989; Rec: 0.1261; F1: 0.2237
# N: 112184
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.3; Accu: 28.86; Pre: 0.9773; Rec: 0.2883; F1: 0.4452
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.3; Accu: 28.61; Pre: 0.9938; Rec: 0.2865; F1: 0.4448
# N: 75781
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.4; Accu: 19.49; Pre: 0.9897; Rec: 0.189; F1: 0.3174
# N: 147674
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.4; Accu: 37.99; Pre: 0.9802; Rec: 0.3815; F1: 0.5492
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.4; Accu: 38.3; Pre: 0.9953; Rec: 0.3836; F1: 0.5538
# N: 99023
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.5; Accu: 25.47; Pre: 0.9899; Rec: 0.2499; F1: 0.3991
# N: 182904
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.5; Accu: 47.05; Pre: 0.9809; Rec: 0.4745; F1: 0.6396
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.5; Accu: 47.35; Pre: 0.9961; Rec: 0.4744; F1: 0.6427
# N: 119550
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.6; Accu: 30.75; Pre: 0.9908; Rec: 0.3035; F1: 0.4647
# N: 227785
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.6; Accu: 58.59; Pre: 0.9838; Rec: 0.5916; F1: 0.7389
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.6; Accu: 60.33; Pre: 0.9969; Rec: 0.6044; F1: 0.7526
# N: 139055
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.7; Accu: 35.77; Pre: 0.9918; Rec: 0.3543; F1: 0.5221
# N: 282105
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.7; Accu: 72.57; Pre: 0.9868; Rec: 0.7328; F1: 0.841
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.7; Accu: 74.56; Pre: 0.9975; Rec: 0.747; F1: 0.8543
# sample_shape: 38873
# num_samples_t 38873
# N: 33703ch
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.2; Accu: 8.67; Pre: 0.999; Rec: 0.07779; F1: 0.1443
# N: 88010
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.2; Accu: 22.64; Pre: 0.9723; Rec: 0.2252; F1: 0.3657
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.2; Accu: 22.33; Pre: 0.9921; Rec: 0.2237; F1: 0.365
# N: 53959
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.3; Accu: 13.88; Pre: 0.999; Rec: 0.1305; F1: 0.2308
# N: 136732
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.3; Accu: 35.17; Pre: 0.9809; Rec: 0.3522; F1: 0.5183
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.3; Accu: 35.69; Pre: 0.9951; Rec: 0.3575; F1: 0.526
# N: 72797
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.4; Accu: 18.73; Pre: 0.9991; Rec: 0.1794; F1: 0.3042
# N: 171057
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.4; Accu: 44.0; Pre: 0.9845; Rec: 0.4415; F1: 0.6096
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.4; Accu: 43.7; Pre: 0.996; Rec: 0.4377; F1: 0.6081
# N: 91430
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.5; Accu: 23.52; Pre: 0.999; Rec: 0.2279; F1: 0.3711
# N: 210301
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.5; Accu: 54.1; Pre: 0.9872; Rec: 0.5435; F1: 0.701
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.5; Accu: 54.66; Pre: 0.9968; Rec: 0.5475; F1: 0.7068
# N: 109609
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.6; Accu: 28.2; Pre: 0.999; Rec: 0.2752; F1: 0.4315
# N: 244849
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.6; Accu: 62.98; Pre: 0.9889; Rec: 0.6333; F1: 0.7721
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.6; Accu: 63.43; Pre: 0.9972; Rec: 0.6354; F1: 0.7762
# N: 124890
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.7; Accu: 32.13; Pre: 0.9988; Rec: 0.315; F1: 0.4789
# N: 284120
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.7; Accu: 73.09; Pre: 0.9901; Rec: 0.7356; F1: 0.8441
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.7; Accu: 73.57; Pre: 0.9975; Rec: 0.7371; F1: 0.8477
# sample_shape: 38873
# num_samples_t 38873
# N: 24284ch
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.2; Accu: 6.247; Pre: 0.9469; Rec: 0.05642; F1: 0.1065
# N: 108606
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.2; Accu: 27.94; Pre: 0.9995; Rec: 0.2724; F1: 0.4281
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.2; Accu: 27.15; Pre: 1.0; Rec: 0.2701; F1: 0.4254
# N: 40816
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.3; Accu: 10.5; Pre: 0.9608; Rec: 0.1003; F1: 0.1816
# N: 164174
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.3; Accu: 42.23; Pre: 0.9991; Rec: 0.417; F1: 0.5884
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.3; Accu: 40.98; Pre: 1.0; Rec: 0.4088; F1: 0.5803
# N: 57137
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.4; Accu: 14.7; Pre: 0.9668; Rec: 0.1435; F1: 0.2499
# N: 202094
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.4; Accu: 51.99; Pre: 0.9969; Rec: 0.5168; F1: 0.6807
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.4; Accu: 51.44; Pre: 0.9998; Rec: 0.5136; F1: 0.6786
# N: 75297
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.5; Accu: 19.37; Pre: 0.9714; Rec: 0.1914; F1: 0.3198
# N: 231601
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.5; Accu: 59.58; Pre: 0.9941; Rec: 0.5953; F1: 0.7447
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.5; Accu: 59.15; Pre: 0.999; Rec: 0.5914; F1: 0.7429
# N: 95738
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.6; Accu: 24.63; Pre: 0.9748; Rec: 0.2452; F1: 0.3918
# N: 264269
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.6; Accu: 67.98; Pre: 0.9904; Rec: 0.6833; F1: 0.8087
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.6; Accu: 68.45; Pre: 0.998; Rec: 0.6852; F1: 0.8126
# N: 115157
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.7; Accu: 29.62; Pre: 0.9775; Rec: 0.2961; F1: 0.4546
# N: 303027
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.7; Accu: 77.95; Pre: 0.9905; Rec: 0.7849; F1: 0.8758
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.7; Accu: 80.0; Pre: 0.9982; Rec: 0.8011; F1: 0.8889
# sample_shape: 38873
# num_samples_t 38873
# N: 27752ch
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.2; Accu: 7.139; Pre: 0.9655; Rec: 0.06456; F1: 0.121
# N: 73394
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.2; Accu: 18.88; Pre: 0.9997; Rec: 0.1809; F1: 0.3063
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.2; Accu: 17.52; Pre: 1.0; Rec: 0.1736; F1: 0.2959
# N: 44735
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.3; Accu: 11.51; Pre: 0.9662; Rec: 0.1102; F1: 0.1979
# N: 108690
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.3; Accu: 27.96; Pre: 0.9963; Rec: 0.2735; F1: 0.4292
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.3; Accu: 27.12; Pre: 0.9998; Rec: 0.2699; F1: 0.4251
# N: 62334
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.4; Accu: 16.03; Pre: 0.97; Rec: 0.1569; F1: 0.2702
# N: 182201
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.4; Accu: 46.87; Pre: 0.9947; Rec: 0.4659; F1: 0.6346
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.4; Accu: 46.84; Pre: 0.9998; Rec: 0.4675; F1: 0.6371
# N: 84388
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.5; Accu: 21.71; Pre: 0.9746; Rec: 0.215; F1: 0.3523
# N: 213418
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.5; Accu: 54.9; Pre: 0.9917; Rec: 0.5491; F1: 0.7069
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.5; Accu: 55.14; Pre: 0.9985; Rec: 0.5514; F1: 0.7105
# N: 111754
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.6; Accu: 28.75; Pre: 0.9783; Rec: 0.2868; F1: 0.4436
# N: 249118
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.6; Accu: 64.08; Pre: 0.9884; Rec: 0.6449; F1: 0.7805
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.6; Accu: 63.82; Pre: 0.9975; Rec: 0.6392; F1: 0.7791
# N: 143699
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.7; Accu: 36.96; Pre: 0.9811; Rec: 0.3706; F1: 0.538
# N: 290831
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.7; Accu: 74.81; Pre: 0.9879; Rec: 0.7549; F1: 0.8558
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.7; Accu: 76.31; Pre: 0.9976; Rec: 0.7645; F1: 0.8657
# sample_shape: 38873
# num_samples_t 38873
# N: 32859ch
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.2; Accu: 8.452; Pre: 0.9651; Rec: 0.07836; F1: 0.145
# N: 98092
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.2; Accu: 25.23; Pre: 0.9859; Rec: 0.2485; F1: 0.397
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.2; Accu: 25.54; Pre: 0.9982; Rec: 0.2545; F1: 0.4056
# N: 48915
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.3; Accu: 12.58; Pre: 0.9695; Rec: 0.121; F1: 0.2152
# N: 127018
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.3; Accu: 32.67; Pre: 0.9855; Rec: 0.3249; F1: 0.4887
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.3; Accu: 32.39; Pre: 0.9986; Rec: 0.3231; F1: 0.4883
# N: 66063
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.4; Accu: 16.99; Pre: 0.9753; Rec: 0.166; F1: 0.2837
# N: 154853
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.4; Accu: 39.83; Pre: 0.9866; Rec: 0.3978; F1: 0.567
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.4; Accu: 40.13; Pre: 0.9987; Rec: 0.4007; F1: 0.572
# N: 82734
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.5; Accu: 21.28; Pre: 0.9795; Rec: 0.2095; F1: 0.3451
# N: 183198
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.5; Accu: 47.12; Pre: 0.9817; Rec: 0.4749; F1: 0.6401
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.5; Accu: 47.64; Pre: 0.9965; Rec: 0.4772; F1: 0.6453
# N: 97907
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.6; Accu: 25.19; Pre: 0.9822; Rec: 0.249; F1: 0.3973
# N: 223764
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.6; Accu: 57.56; Pre: 0.9837; Rec: 0.5811; F1: 0.7306
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.6; Accu: 58.04; Pre: 0.9968; Rec: 0.5815; F1: 0.7345
# N: 111673
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.7; Accu: 28.73; Pre: 0.9839; Rec: 0.2849; F1: 0.4419
# N: 257765
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.7; Accu: 66.31; Pre: 0.9857; Rec: 0.6694; F1: 0.7974
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.7; Accu: 67.16; Pre: 0.9972; Rec: 0.6728; F1: 0.8035
# sample_shape: 38873
# num_samples_t 38873
# N: 26079ch
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.2; Accu: 6.708; Pre: 0.9947; Rec: 0.05822; F1: 0.11
# N: 87329
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.2; Accu: 22.46; Pre: 0.9988; Rec: 0.2173; F1: 0.3569
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.2; Accu: 22.13; Pre: 1.0; Rec: 0.2199; F1: 0.3605
# N: 42172
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.3; Accu: 10.85; Pre: 0.9944; Rec: 0.1003; F1: 0.1822
# N: 141278
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.3; Accu: 36.34; Pre: 0.9888; Rec: 0.3613; F1: 0.5292
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.3; Accu: 36.29; Pre: 0.9963; Rec: 0.3631; F1: 0.5322
# N: 57698
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.4; Accu: 14.84; Pre: 0.9941; Rec: 0.1409; F1: 0.2468
# N: 186602
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.4; Accu: 48.0; Pre: 0.9902; Rec: 0.4796; F1: 0.6462
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.4; Accu: 48.73; Pre: 0.9972; Rec: 0.4877; F1: 0.655
# N: 73796
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.5; Accu: 18.98; Pre: 0.9938; Rec: 0.183; F1: 0.3091
# N: 216271
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.5; Accu: 55.63; Pre: 0.991; Rec: 0.557; F1: 0.7132
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.5; Accu: 55.25; Pre: 0.9974; Rec: 0.5531; F1: 0.7116
# N: 90762
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.6; Accu: 23.35; Pre: 0.9935; Rec: 0.2274; F1: 0.3701
# N: 245031
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.6; Accu: 63.03; Pre: 0.9912; Rec: 0.6323; F1: 0.7721
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.6; Accu: 63.32; Pre: 0.9978; Rec: 0.6339; F1: 0.7753
# N: 107804
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.7; Accu: 27.73; Pre: 0.9927; Rec: 0.2722; F1: 0.4273
# N: 279226
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.7; Accu: 71.83; Pre: 0.9905; Rec: 0.7224; F1: 0.8355
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.7; Accu: 71.05; Pre: 0.9979; Rec: 0.7115; F1: 0.8307
# sample_shape: 38873
# num_samples_t 38873
# N: 32547ch
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.2; Accu: 8.372; Pre: 0.997; Rec: 0.07494; F1: 0.1394
# N: 93593
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.2; Accu: 24.08; Pre: 0.9729; Rec: 0.24; F1: 0.385
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.2; Accu: 23.66; Pre: 0.9923; Rec: 0.237; F1: 0.3827
# N: 53655
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.3; Accu: 13.8; Pre: 0.9971; Rec: 0.1299; F1: 0.2299
# N: 135640
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.3; Accu: 34.89; Pre: 0.9771; Rec: 0.3507; F1: 0.5162
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.3; Accu: 34.92; Pre: 0.9947; Rec: 0.3499; F1: 0.5177
# N: 75059
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.4; Accu: 19.31; Pre: 0.997; Rec: 0.1857; F1: 0.3131
# N: 189325
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.4; Accu: 48.7; Pre: 0.9821; Rec: 0.4909; F1: 0.6546
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.4; Accu: 49.67; Pre: 0.9963; Rec: 0.4976; F1: 0.6637
# N: 98580
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.5; Accu: 25.36; Pre: 0.997; Rec: 0.247; F1: 0.3959
# N: 230803
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.5; Accu: 59.37; Pre: 0.9845; Rec: 0.5991; F1: 0.7449
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.5; Accu: 59.69; Pre: 0.9969; Rec: 0.5981; F1: 0.7476
# N: 121413
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.6; Accu: 31.23; Pre: 0.997; Rec: 0.3065; F1: 0.4688
# N: 266026
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.6; Accu: 68.43; Pre: 0.9863; Rec: 0.6908; F1: 0.8125
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.6; Accu: 69.14; Pre: 0.9973; Rec: 0.6927; F1: 0.8175
# N: 142071
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.7; Accu: 36.55; Pre: 0.9969; Rec: 0.3603; F1: 0.5293
# N: 302179
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.7; Accu: 77.73; Pre: 0.9878; Rec: 0.7848; F1: 0.8747
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.7; Accu: 79.38; Pre: 0.9977; Rec: 0.7953; F1: 0.8851
# sample_shape: 38873
# num_samples_t 38873
# N: 27952ch
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.2; Accu: 7.19; Pre: 0.9963; Rec: 0.06301; F1: 0.1185
# N: 100484
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.2; Accu: 25.85; Pre: 0.9891; Rec: 0.254; F1: 0.4042
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.2; Accu: 26.38; Pre: 0.9985; Rec: 0.2628; F1: 0.4161
# N: 44809
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.3; Accu: 11.53; Pre: 0.9959; Rec: 0.107; F1: 0.1933
# N: 150708
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.3; Accu: 38.77; Pre: 0.9917; Rec: 0.3849; F1: 0.5545
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.3; Accu: 38.32; Pre: 0.999; Rec: 0.3825; F1: 0.5532
# N: 66288
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.4; Accu: 17.05; Pre: 0.9956; Rec: 0.1631; F1: 0.2803
# N: 188414
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.4; Accu: 48.47; Pre: 0.9872; Rec: 0.4859; F1: 0.6512
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.4; Accu: 49.26; Pre: 0.9968; Rec: 0.4932; F1: 0.6599
# N: 87587
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.5; Accu: 22.53; Pre: 0.9948; Rec: 0.2188; F1: 0.3588
# N: 218748
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.5; Accu: 56.27; Pre: 0.9878; Rec: 0.5654; F1: 0.7191
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.5; Accu: 56.23; Pre: 0.9969; Rec: 0.5633; F1: 0.7198
# N: 107719
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.6; Accu: 27.71; Pre: 0.9938; Rec: 0.2717; F1: 0.4267
# N: 256492
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.6; Accu: 65.98; Pre: 0.9895; Rec: 0.6635; F1: 0.7943
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.6; Accu: 66.91; Pre: 0.9974; Rec: 0.6703; F1: 0.8018
# N: 123212
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.7; Accu: 31.69; Pre: 0.9923; Rec: 0.3126; F1: 0.4755
# N: 291869
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.7; Accu: 75.08; Pre: 0.9906; Rec: 0.7555; F1: 0.8572
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.7; Accu: 74.96; Pre: 0.9976; Rec: 0.7509; F1: 0.8568
# sample_shape: 38873
# num_samples_t 38873
# N: 23709ch
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.2; Accu: 6.099; Pre: 0.9573; Rec: 0.05418; F1: 0.1025
# N: 93187
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.2; Accu: 23.97; Pre: 0.9881; Rec: 0.2351; F1: 0.3798
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.2; Accu: 23.19; Pre: 0.9997; Rec: 0.2305; F1: 0.3746
# N: 40852
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.3; Accu: 10.51; Pre: 0.9679; Rec: 0.0996; F1: 0.1806
# N: 134547
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.3; Accu: 34.61; Pre: 0.9916; Rec: 0.3426; F1: 0.5092
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.3; Accu: 34.27; Pre: 0.9998; Rec: 0.3416; F1: 0.5092
# N: 58911
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.4; Accu: 15.15; Pre: 0.974; Rec: 0.1471; F1: 0.2556
# N: 171495
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.4; Accu: 44.11; Pre: 0.9934; Rec: 0.4386; F1: 0.6085
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.4; Accu: 44.11; Pre: 0.9998; Rec: 0.4401; F1: 0.6112
# N: 77109
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.5; Accu: 19.84; Pre: 0.9771; Rec: 0.195; F1: 0.3252
# N: 207105
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.5; Accu: 53.27; Pre: 0.9928; Rec: 0.532; F1: 0.6928
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.5; Accu: 53.38; Pre: 0.9994; Rec: 0.5333; F1: 0.6954
# N: 92716
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.6; Accu: 23.85; Pre: 0.9778; Rec: 0.2364; F1: 0.3807
# N: 232042
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.6; Accu: 59.69; Pre: 0.9886; Rec: 0.5998; F1: 0.7467
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.6; Accu: 60.11; Pre: 0.9986; Rec: 0.6011; F1: 0.7505
# N: 105646
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.7; Accu: 27.18; Pre: 0.978; Rec: 0.2707; F1: 0.424
# N: 260491
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.7; Accu: 67.01; Pre: 0.9861; Rec: 0.6764; F1: 0.8024
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.7; Accu: 67.44; Pre: 0.9973; Rec: 0.6756; F1: 0.8055
# sample_shape: 38873
# num_samples_t 38873
# N: 15269ch
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.2; Accu: 3.928; Pre: 0.9766; Rec: 0.03057; F1: 0.05928
# N: 109938
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.2; Accu: 28.28; Pre: 0.9908; Rec: 0.2783; F1: 0.4346
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.2; Accu: 26.67; Pre: 0.9985; Rec: 0.2657; F1: 0.4197
# N: 27670
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.3; Accu: 7.118; Pre: 0.9789; Rec: 0.06341; F1: 0.1191
# N: 164339
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.3; Accu: 42.27; Pre: 0.9933; Rec: 0.4199; F1: 0.5903
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.3; Accu: 41.79; Pre: 0.9991; Rec: 0.4172; F1: 0.5886
# N: 39385
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.4; Accu: 10.13; Pre: 0.981; Rec: 0.0943; F1: 0.1721
# N: 214760
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.4; Accu: 55.24; Pre: 0.9943; Rec: 0.5512; F1: 0.7092
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.4; Accu: 55.59; Pre: 0.9993; Rec: 0.5555; F1: 0.714
# N: 56127
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.5; Accu: 14.44; Pre: 0.9841; Rec: 0.1382; F1: 0.2424
# N: 232510
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.5; Accu: 59.81; Pre: 0.9937; Rec: 0.5979; F1: 0.7466
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.5; Accu: 59.65; Pre: 0.9994; Rec: 0.5962; F1: 0.7468
# N: 74831
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.6; Accu: 19.25; Pre: 0.9866; Rec: 0.1871; F1: 0.3145
# N: 258721
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.6; Accu: 66.55; Pre: 0.9925; Rec: 0.6673; F1: 0.798
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.6; Accu: 66.5; Pre: 0.9994; Rec: 0.6648; F1: 0.7984
# N: 94563
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.7; Accu: 24.32; Pre: 0.9883; Rec: 0.2386; F1: 0.3844
# N: 287418
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.7; Accu: 73.93; Pre: 0.9918; Rec: 0.7429; F1: 0.8495
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.7; Accu: 74.47; Pre: 0.9991; Rec: 0.7449; F1: 0.8535
# sample_shape: 38873
# num_samples_t 38873
# N: 29761ch
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.2; Accu: 7.656; Pre: 0.9966; Rec: 0.06771; F1: 0.1268
# N: 101696
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.2; Accu: 26.16; Pre: 0.9754; Rec: 0.2609; F1: 0.4117
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.2; Accu: 26.64; Pre: 0.9934; Rec: 0.2668; F1: 0.4206
# N: 49534
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.3; Accu: 12.74; Pre: 0.9956; Rec: 0.1194; F1: 0.2132
# N: 138138
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.3; Accu: 35.53; Pre: 0.9813; Rec: 0.3558; F1: 0.5222
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.3; Accu: 34.87; Pre: 0.9949; Rec: 0.3492; F1: 0.517
# N: 72556
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.4; Accu: 18.66; Pre: 0.9955; Rec: 0.1795; F1: 0.3041
# N: 161569
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.4; Accu: 41.56; Pre: 0.9835; Rec: 0.4169; F1: 0.5855
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.4; Accu: 41.6; Pre: 0.9958; Rec: 0.4167; F1: 0.5876
# N: 90021
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.5; Accu: 23.16; Pre: 0.9951; Rec: 0.2251; F1: 0.3672
# N: 209097
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.5; Accu: 53.79; Pre: 0.9865; Rec: 0.5407; F1: 0.6986
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.5; Accu: 53.94; Pre: 0.9967; Rec: 0.5404; F1: 0.7008
# N: 105737
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.6; Accu: 27.2; Pre: 0.9949; Rec: 0.2662; F1: 0.42
# N: 237188
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.6; Accu: 61.01; Pre: 0.9871; Rec: 0.6143; F1: 0.7573
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.6; Accu: 61.78; Pre: 0.9971; Rec: 0.6189; F1: 0.7637
# N: 119754
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.7; Accu: 30.8; Pre: 0.9947; Rec: 0.3029; F1: 0.4643
# N: 276714
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.7; Accu: 71.18; Pre: 0.988; Rec: 0.7177; F1: 0.8314
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.7; Accu: 71.41; Pre: 0.9974; Rec: 0.7154; F1: 0.8332
# sample_shape: 38873
# num_samples_t 38873
# N: 28072ch
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.2; Accu: 7.221; Pre: 0.9879; Rec: 0.06387; F1: 0.12
# N: 86796
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.2; Accu: 22.33; Pre: 0.9821; Rec: 0.2196; F1: 0.359
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.2; Accu: 22.37; Pre: 0.994; Rec: 0.2236; F1: 0.365
# N: 45197
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.3; Accu: 11.63; Pre: 0.9854; Rec: 0.1092; F1: 0.1966
# N: 149121
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.3; Accu: 38.36; Pre: 0.9887; Rec: 0.3819; F1: 0.551
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.3; Accu: 38.08; Pre: 0.9964; Rec: 0.381; F1: 0.5512
# N: 65531
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.4; Accu: 16.86; Pre: 0.9854; Rec: 0.1628; F1: 0.2794
# N: 193116
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.4; Accu: 49.68; Pre: 0.9907; Rec: 0.4965; F1: 0.6615
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.4; Accu: 49.6; Pre: 0.9972; Rec: 0.4965; F1: 0.6629
# N: 89795
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.5; Accu: 23.1; Pre: 0.9884; Rec: 0.2261; F1: 0.368
# N: 218641
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.5; Accu: 56.24; Pre: 0.9878; Rec: 0.5651; F1: 0.7189
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.5; Accu: 56.06; Pre: 0.9968; Rec: 0.5616; F1: 0.7184
# N: 111847
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.6; Accu: 28.77; Pre: 0.9904; Rec: 0.2834; F1: 0.4408
# N: 265122
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.6; Accu: 68.2; Pre: 0.9898; Rec: 0.6859; F1: 0.8103
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.6; Accu: 69.08; Pre: 0.9974; Rec: 0.692; F1: 0.8171
# N: 131381
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.7; Accu: 33.8; Pre: 0.9917; Rec: 0.3342; F1: 0.5
# N: 310312
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.7; Accu: 79.82; Pre: 0.9911; Rec: 0.8035; F1: 0.8875
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.7; Accu: 80.71; Pre: 0.9978; Rec: 0.8086; F1: 0.8933
# sample_shape: 38873
# num_samples_t 38873
# N: 22697ch
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.2; Accu: 5.838; Pre: 0.9985; Rec: 0.0492; F1: 0.09378
# N: 87832
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.2; Accu: 22.59; Pre: 0.9705; Rec: 0.2252; F1: 0.3655
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.2; Accu: 22.3; Pre: 0.9935; Rec: 0.223; F1: 0.3643
# N: 34587
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.3; Accu: 8.897; Pre: 0.9974; Rec: 0.08022; F1: 0.1485
# N: 138601
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.3; Accu: 35.65; Pre: 0.9807; Rec: 0.3572; F1: 0.5237
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.3; Accu: 36.04; Pre: 0.9959; Rec: 0.3607; F1: 0.5296
# N: 47645
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.4; Accu: 12.26; Pre: 0.9965; Rec: 0.1143; F1: 0.2051
# N: 166310
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.4; Accu: 42.78; Pre: 0.9839; Rec: 0.4292; F1: 0.5977
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.4; Accu: 42.55; Pre: 0.9966; Rec: 0.4259; F1: 0.5968
# N: 61025
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.5; Accu: 15.7; Pre: 0.9953; Rec: 0.1494; F1: 0.2598
# N: 187865
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.5; Accu: 48.33; Pre: 0.9856; Rec: 0.4853; F1: 0.6503
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.5; Accu: 49.01; Pre: 0.997; Rec: 0.4906; F1: 0.6576
# N: 76753
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.6; Accu: 19.74; Pre: 0.9938; Rec: 0.1907; F1: 0.32
# N: 216837
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.6; Accu: 55.78; Pre: 0.9868; Rec: 0.5609; F1: 0.7153
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.6; Accu: 56.0; Pre: 0.9973; Rec: 0.5607; F1: 0.7178
# N: 90955
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.7; Accu: 23.4; Pre: 0.9924; Rec: 0.2282; F1: 0.3711
# N: 253605
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.7; Accu: 65.24; Pre: 0.986; Rec: 0.6583; F1: 0.7895
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.7; Accu: 66.09; Pre: 0.9972; Rec: 0.6621; F1: 0.7958
# sample_shape: 38873
# num_samples_t 38873
# N: 32950ch
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.2; Accu: 8.476; Pre: 0.9847; Rec: 0.07695; F1: 0.1428
# N: 83429
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.2; Accu: 21.46; Pre: 0.9998; Rec: 0.2069; F1: 0.3429
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.2; Accu: 20.45; Pre: 1.0; Rec: 0.203; F1: 0.3375
# N: 55882
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.3; Accu: 14.37; Pre: 0.985; Rec: 0.1374; F1: 0.2412
# N: 110867
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.3; Accu: 28.52; Pre: 0.9994; Rec: 0.2783; F1: 0.4354
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.3; Accu: 27.82; Pre: 1.0; Rec: 0.2769; F1: 0.4337
# N: 76868
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.4; Accu: 19.77; Pre: 0.9867; Rec: 0.1924; F1: 0.3221
# N: 150640
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.4; Accu: 38.75; Pre: 0.9988; Rec: 0.3819; F1: 0.5526
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.4; Accu: 38.5; Pre: 0.9999; Rec: 0.3839; F1: 0.5548
# N: 98195
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.5; Accu: 25.26; Pre: 0.9886; Rec: 0.2481; F1: 0.3967
# N: 193719
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.5; Accu: 49.83; Pre: 0.9952; Rec: 0.4958; F1: 0.6618
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.5; Accu: 49.15; Pre: 0.9992; Rec: 0.4909; F1: 0.6584
# N: 118384
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.6; Accu: 30.45; Pre: 0.9901; Rec: 0.3007; F1: 0.4613
# N: 232106
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.6; Accu: 59.71; Pre: 0.9947; Rec: 0.5963; F1: 0.7456
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.6; Accu: 59.77; Pre: 0.9994; Rec: 0.5973; F1: 0.7477
# N: 140395
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.7; Accu: 36.11; Pre: 0.9912; Rec: 0.358; F1: 0.5261
# N: 277880
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.7; Accu: 71.48; Pre: 0.995; Rec: 0.7156; F1: 0.8325
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.7; Accu: 71.51; Pre: 0.9995; Rec: 0.7149; F1: 0.8336
# sample_shape: 38873
# num_samples_t 38873
# N: 32857ch
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.2; Accu: 8.452; Pre: 0.999; Rec: 0.0756; F1: 0.1406
# N: 109652
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.2; Accu: 28.21; Pre: 0.99; Rec: 0.2778; F1: 0.4339
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.2; Accu: 27.06; Pre: 0.9986; Rec: 0.2696; F1: 0.4246
# N: 58988
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.3; Accu: 15.17; Pre: 0.9987; Rec: 0.1436; F1: 0.2511
# N: 160388
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.3; Accu: 41.26; Pre: 0.9931; Rec: 0.4097; F1: 0.58
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.3; Accu: 39.78; Pre: 0.999; Rec: 0.397; F1: 0.5682
# N: 86079
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.4; Accu: 22.14; Pre: 0.9987; Rec: 0.2141; F1: 0.3525
# N: 214621
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.4; Accu: 55.21; Pre: 0.9948; Rec: 0.5506; F1: 0.7088
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.4; Accu: 54.89; Pre: 0.9993; Rec: 0.5485; F1: 0.7082
# N: 109975
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.5; Accu: 28.29; Pre: 0.9986; Rec: 0.2762; F1: 0.4328
# N: 259921
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.5; Accu: 66.86; Pre: 0.9955; Rec: 0.6684; F1: 0.7998
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.5; Accu: 66.94; Pre: 0.9994; Rec: 0.6692; F1: 0.8016
# N: 130956
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.6; Accu: 33.69; Pre: 0.9986; Rec: 0.3308; F1: 0.497
# N: 302548
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.6; Accu: 77.83; Pre: 0.9959; Rec: 0.7793; F1: 0.8744
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.6; Accu: 78.71; Pre: 0.9995; Rec: 0.7871; F1: 0.8807
# N: 149194
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.7; Accu: 38.38; Pre: 0.9985; Rec: 0.3783; F1: 0.5487
# N: 334108
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.7; Accu: 85.94; Pre: 0.9958; Rec: 0.8617; F1: 0.9239
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.7; Accu: 85.87; Pre: 0.9996; Rec: 0.8589; F1: 0.9239
# sample_shape: 38873
# num_samples_t 38873
# N: 24096ch
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.2; Accu: 6.198; Pre: 0.97; Rec: 0.05445; F1: 0.1031
# N: 117246
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.2; Accu: 30.16; Pre: 0.9998; Rec: 0.2948; F1: 0.4553
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.2; Accu: 29.86; Pre: 1.0; Rec: 0.2973; F1: 0.4583
# N: 45380
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.3; Accu: 11.67; Pre: 0.9783; Rec: 0.1105; F1: 0.1986
# N: 148389
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.3; Accu: 38.17; Pre: 0.9996; Rec: 0.3758; F1: 0.5462
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.3; Accu: 36.96; Pre: 1.0; Rec: 0.3685; F1: 0.5385
# N: 67602
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.4; Accu: 17.39; Pre: 0.9826; Rec: 0.1688; F1: 0.2881
# N: 191236
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.4; Accu: 49.19; Pre: 0.9993; Rec: 0.4873; F1: 0.6551
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.4; Accu: 48.5; Pre: 1.0; Rec: 0.484; F1: 0.6523
# N: 85867
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.5; Accu: 22.09; Pre: 0.9843; Rec: 0.2167; F1: 0.3552
# N: 230437
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.5; Accu: 59.28; Pre: 0.997; Rec: 0.5905; F1: 0.7417
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.5; Accu: 58.64; Pre: 0.9995; Rec: 0.586; F1: 0.7388
# N: 102750
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.6; Accu: 26.43; Pre: 0.9854; Rec: 0.2609; F1: 0.4126
# N: 263143
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.6; Accu: 67.69; Pre: 0.9949; Rec: 0.6772; F1: 0.8059
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.6; Accu: 67.81; Pre: 0.9994; Rec: 0.6779; F1: 0.8078
# N: 119854
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.7; Accu: 30.83; Pre: 0.986; Rec: 0.3058; F1: 0.4669
# N: 291133
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.7; Accu: 74.89; Pre: 0.9934; Rec: 0.7514; F1: 0.8556
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.7; Accu: 75.42; Pre: 0.9995; Rec: 0.7541; F1: 0.8596
# sample_shape: 38873
# num_samples_t 38873
# N: 31129ch
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.2; Accu: 8.007; Pre: 0.9949; Rec: 0.0714; F1: 0.1332
# N: 110400
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.2; Accu: 28.4; Pre: 0.9968; Rec: 0.2778; F1: 0.4345
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.2; Accu: 27.48; Pre: 0.9998; Rec: 0.2735; F1: 0.4295
# N: 53463
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.3; Accu: 13.75; Pre: 0.9951; Rec: 0.1297; F1: 0.2295
# N: 158849
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.3; Accu: 40.86; Pre: 0.9935; Rec: 0.4055; F1: 0.5759
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.3; Accu: 40.65; Pre: 0.9993; Rec: 0.4057; F1: 0.5771
# N: 69517
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.4; Accu: 17.88; Pre: 0.9946; Rec: 0.1717; F1: 0.2928
# N: 204516
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.4; Accu: 52.61; Pre: 0.9917; Rec: 0.5258; F1: 0.6873
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.4; Accu: 52.74; Pre: 0.9991; Rec: 0.527; F1: 0.6901
# N: 82281
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.5; Accu: 21.17; Pre: 0.9935; Rec: 0.2053; F1: 0.3402
# N: 239914
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.5; Accu: 61.71; Pre: 0.9919; Rec: 0.6184; F1: 0.7619
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.5; Accu: 61.62; Pre: 0.9992; Rec: 0.616; F1: 0.7621
# N: 97266
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.6; Accu: 25.02; Pre: 0.993; Rec: 0.2446; F1: 0.3925
# N: 275446
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.6; Accu: 70.85; Pre: 0.9925; Rec: 0.7111; F1: 0.8285
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.6; Accu: 71.41; Pre: 0.9994; Rec: 0.7141; F1: 0.833
# N: 114183
# seq_length: 30
# Comb-logits-based-Epoch: 20; tao=0.7; Accu: 29.37; Pre: 0.9922; Rec: 0.289; F1: 0.4477
# N: 299338
# seq_length: 30
# Comb-statistic-based-Epoch: 20; tao=0.7; Accu: 77.0; Pre: 0.9928; Rec: 0.7733; F1: 0.8694
# seq_length: 30
# sample-wise-Epoch: 20; tao=0.7; Accu: 77.0; Pre: 0.9994; Rec: 0.7701; F1: 0.8699
# sample_shape: 38873
# num_samples_t 38873
# N: 22023ch
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.2; Accu: 5.665; Pre: 0.9933; Rec: 0.0477; F1: 0.09102
# N: 65512
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.2; Accu: 16.85; Pre: 0.9999; Rec: 0.1604; F1: 0.2764
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.2; Accu: 16.1; Pre: 1.0; Rec: 0.1594; F1: 0.275
# N: 42034
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.3; Accu: 10.81; Pre: 0.9939; Rec: 0.09997; F1: 0.1817
# N: 112945
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.3; Accu: 29.05; Pre: 0.9977; Rec: 0.2842; F1: 0.4424
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.3; Accu: 27.77; Pre: 1.0; Rec: 0.2763; F1: 0.433
# N: 62958
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.4; Accu: 16.19; Pre: 0.9945; Rec: 0.1546; F1: 0.2676
# N: 161013
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.4; Accu: 41.42; Pre: 0.9952; Rec: 0.4104; F1: 0.5812
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.4; Accu: 40.46; Pre: 0.9996; Rec: 0.4036; F1: 0.5751
# N: 83895
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.5; Accu: 21.58; Pre: 0.9942; Rec: 0.2093; F1: 0.3458
# N: 190407
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.5; Accu: 48.98; Pre: 0.9947; Rec: 0.4874; F1: 0.6542
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.5; Accu: 48.7; Pre: 0.9994; Rec: 0.4864; F1: 0.6543
# N: 107632
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.6; Accu: 27.69; Pre: 0.9937; Rec: 0.2715; F1: 0.4265
# N: 228181
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.6; Accu: 58.7; Pre: 0.9951; Rec: 0.5858; F1: 0.7375
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.6; Accu: 58.19; Pre: 0.9993; Rec: 0.5815; F1: 0.7352
# N: 132428
# seq_length: 30
# Comb-logits-based-Epoch: 21; tao=0.7; Accu: 34.07; Pre: 0.9929; Rec: 0.3366; F1: 0.5027
# N: 279281
# seq_length: 30
# Comb-statistic-based-Epoch: 21; tao=0.7; Accu: 71.84; Pre: 0.9942; Rec: 0.7199; F1: 0.8351
# seq_length: 30
# sample-wise-Epoch: 21; tao=0.7; Accu: 72.19; Pre: 0.9991; Rec: 0.7221; F1: 0.8383
# sample_shape: 38873
# num_samples_t 38873
# N: 41289ch
# seq_length: 30
# Comb-logits-based-Epoch: 22; tao=0.2; Accu: 10.62; Pre: 0.9994; Rec: 0.09748; F1: 0.1776
# N: 118568
# seq_length: 30
# Comb-statistic-based-Epoch: 22; tao=0.2; Accu: 30.5; Pre: 0.9899; Rec: 0.3012; F1: 0.4619
# seq_length: 30
# sample-wise-Epoch: 22; tao=0.2; Accu: 30.23; Pre: 0.9997; Rec: 0.3012; F1: 0.4629
# N: 60104
# seq_length: 30
# Comb-logits-based-Epoch: 22; tao=0.3; Accu: 15.46; Pre: 0.999; Rec: 0.1464; F1: 0.2554
# N: 151351
# seq_length: 30
# Comb-statistic-based-Epoch: 22; tao=0.3; Accu: 38.93; Pre: 0.9842; Rec: 0.3896; F1: 0.5582
# seq_length: 30
# sample-wise-Epoch: 22; tao=0.3; Accu: 38.91; Pre: 0.9974; Rec: 0.389; F1: 0.5597
# N: 83336
# seq_length: 30
# Comb-logits-based-Epoch: 22; tao=0.4; Accu: 21.44; Pre: 0.9984; Rec: 0.207; F1: 0.3429
# N: 184992
# seq_length: 30
# Comb-statistic-based-Epoch: 22; tao=0.4; Accu: 47.59; Pre: 0.9809; Rec: 0.48; F1: 0.6446
# seq_length: 30
# sample-wise-Epoch: 22; tao=0.4; Accu: 47.68; Pre: 0.9961; Rec: 0.4777; F1: 0.6458
# N: 102384
# seq_length: 30
# Comb-logits-based-Epoch: 22; tao=0.5; Accu: 26.34; Pre: 0.9975; Rec: 0.2568; F1: 0.4084
# N: 227310
# seq_length: 30
# Comb-statistic-based-Epoch: 22; tao=0.5; Accu: 58.47; Pre: 0.984; Rec: 0.5903; F1: 0.7379
# seq_length: 30
# sample-wise-Epoch: 22; tao=0.5; Accu: 59.52; Pre: 0.9969; Rec: 0.5963; F1: 0.7462
# N: 118425
# seq_length: 30
# Comb-logits-based-Epoch: 22; tao=0.6; Accu: 30.46; Pre: 0.9962; Rec: 0.2989; F1: 0.4599
# N: 269910
# seq_length: 30
# Comb-statistic-based-Epoch: 22; tao=0.6; Accu: 69.43; Pre: 0.9864; Rec: 0.701; F1: 0.8195
# seq_length: 30
# ...
# sample_shape: 38873
# num_samples_t 38873
# N: 24876ch
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.2; Accu: 6.399; Pre: 0.9735; Rec: 0.05632; F1: 0.1065
# N: 103830
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.2; Accu: 26.71; Pre: 0.985; Rec: 0.2639; F1: 0.4163
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.2; Accu: 26.14; Pre: 0.9947; Rec: 0.2615; F1: 0.4141
# N: 45706
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.3; Accu: 11.76; Pre: 0.9779; Rec: 0.1114; F1: 0.2
# N: 131670
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.3; Accu: 33.87; Pre: 0.9876; Rec: 0.3364; F1: 0.5019
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.3; Accu: 33.18; Pre: 0.9958; Rec: 0.332; F1: 0.4979
# N: 66090
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.4; Accu: 17.0; Pre: 0.9805; Rec: 0.1651; F1: 0.2827
# N: 169869
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.4; Accu: 43.7; Pre: 0.9903; Rec: 0.4357; F1: 0.6051
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.4; Accu: 42.53; Pre: 0.9967; Rec: 0.4257; F1: 0.5966
# N: 86167
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.5; Accu: 22.17; Pre: 0.983; Rec: 0.2178; F1: 0.3566
# N: 206956
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.5; Accu: 53.24; Pre: 0.9892; Rec: 0.5336; F1: 0.6932
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.5; Accu: 52.77; Pre: 0.9969; Rec: 0.5285; F1: 0.6908
# N: 110431
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.6; Accu: 28.41; Pre: 0.9855; Rec: 0.2812; F1: 0.4375
# N: 238683
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.6; Accu: 61.4; Pre: 0.9878; Rec: 0.6178; F1: 0.7602
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.6; Accu: 61.65; Pre: 0.9972; Rec: 0.6176; F1: 0.7628
# N: 130223
# seq_length: 30
# Comb-logits-based-Epoch: 92; tao=0.7; Accu: 33.5; Pre: 0.9869; Rec: 0.3328; F1: 0.4978
# N: 283312
# seq_length: 30
# Comb-statistic-based-Epoch: 92; tao=0.7; Accu: 72.88; Pre: 0.9879; Rec: 0.7351; F1: 0.843
# seq_length: 30
# sample-wise-Epoch: 92; tao=0.7; Accu: 74.92; Pre: 0.9975; Rec: 0.7506; F1: 0.8566
# sample_shape: 38873
# num_samples_t 38873
# N: 28487ch
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.2; Accu: 7.328; Pre: 0.9905; Rec: 0.06479; F1: 0.1216
# N: 103978
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.2; Accu: 26.75; Pre: 0.9998; Rec: 0.2603; F1: 0.4131
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.2; Accu: 25.45; Pre: 1.0; Rec: 0.2531; F1: 0.4039
# N: 47833
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.3; Accu: 12.3; Pre: 0.9871; Rec: 0.1159; F1: 0.2075
# N: 156641
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.3; Accu: 40.29; Pre: 0.9997; Rec: 0.3972; F1: 0.5685
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.3; Accu: 39.09; Pre: 1.0; Rec: 0.3897; F1: 0.5609
# N: 68783
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.4; Accu: 17.69; Pre: 0.9862; Rec: 0.1712; F1: 0.2918
# N: 217052
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.4; Accu: 55.83; Pre: 0.9992; Rec: 0.5544; F1: 0.7131
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.4; Accu: 55.31; Pre: 1.0; Rec: 0.5523; F1: 0.7116
# N: 88361
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.5; Accu: 22.73; Pre: 0.9857; Rec: 0.2229; F1: 0.3636
# N: 260218
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.5; Accu: 66.94; Pre: 0.9979; Rec: 0.6675; F1: 0.7999
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.5; Accu: 66.73; Pre: 0.9993; Rec: 0.6672; F1: 0.8001
# N: 106941
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.6; Accu: 27.51; Pre: 0.9861; Rec: 0.2718; F1: 0.4261
# N: 287674
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.6; Accu: 74.0; Pre: 0.9952; Rec: 0.741; F1: 0.8495
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.6; Accu: 74.23; Pre: 0.9986; Rec: 0.7429; F1: 0.852
# N: 124991
# seq_length: 30
# Comb-logits-based-Epoch: 93; tao=0.7; Accu: 32.15; Pre: 0.9864; Rec: 0.3192; F1: 0.4824
# N: 309430
# seq_length: 30
# Comb-statistic-based-Epoch: 93; tao=0.7; Accu: 79.6; Pre: 0.9935; Rec: 0.7992; F1: 0.8858
# seq_length: 30
# sample-wise-Epoch: 93; tao=0.7; Accu: 79.44; Pre: 0.9983; Rec: 0.7954; F1: 0.8853
# sample_shape: 38873
# num_samples_t 38873
# N: 34487ch
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.2; Accu: 8.871; Pre: 0.9855; Rec: 0.08094; F1: 0.1496
# N: 81014
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.2; Accu: 20.84; Pre: 0.9923; Rec: 0.2022; F1: 0.3359
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.2; Accu: 20.35; Pre: 0.9997; Rec: 0.2021; F1: 0.3362
# N: 61451
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.3; Accu: 15.81; Pre: 0.9854; Rec: 0.152; F1: 0.2634
# N: 116837
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.3; Accu: 30.05; Pre: 0.9925; Rec: 0.2959; F1: 0.4559
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.3; Accu: 29.6; Pre: 0.9994; Rec: 0.2949; F1: 0.4554
# N: 84397
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.4; Accu: 21.71; Pre: 0.9825; Rec: 0.2132; F1: 0.3504
# N: 139980
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.4; Accu: 36.01; Pre: 0.9915; Rec: 0.3568; F1: 0.5248
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.4; Accu: 34.91; Pre: 0.9992; Rec: 0.3482; F1: 0.5164
# N: 103263
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.5; Accu: 26.56; Pre: 0.9782; Rec: 0.2643; F1: 0.4162
# N: 179267
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.5; Accu: 46.11; Pre: 0.9898; Rec: 0.4606; F1: 0.6286
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.5; Accu: 45.95; Pre: 0.999; Rec: 0.4589; F1: 0.6289
# N: 117750
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.6; Accu: 30.29; Pre: 0.9782; Rec: 0.3028; F1: 0.4624
# N: 228023
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.6; Accu: 58.66; Pre: 0.9861; Rec: 0.5908; F1: 0.7389
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.6; Accu: 60.57; Pre: 0.997; Rec: 0.6068; F1: 0.7544
# N: 129401
# seq_length: 30
# Comb-logits-based-Epoch: 94; tao=0.7; Accu: 33.29; Pre: 0.979; Rec: 0.3334; F1: 0.4975
# N: 260415
# seq_length: 30
# Comb-statistic-based-Epoch: 94; tao=0.7; Accu: 66.99; Pre: 0.9858; Rec: 0.6764; F1: 0.8023
# seq_length: 30
# sample-wise-Epoch: 94; tao=0.7; Accu: 67.67; Pre: 0.9973; Rec: 0.678; F1: 0.8072
# sample_shape: 38873
# num_samples_t 38873
# N: 37009ch
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.2; Accu: 9.52; Pre: 0.9997; Rec: 0.08633; F1: 0.1589
# N: 123348
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.2; Accu: 31.73; Pre: 0.987; Rec: 0.3147; F1: 0.4773
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.2; Accu: 32.98; Pre: 0.9958; Rec: 0.3299; F1: 0.4957
# N: 57155
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.3; Accu: 14.7; Pre: 0.9997; Rec: 0.1387; F1: 0.2436
# N: 173432
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.3; Accu: 44.61; Pre: 0.9904; Rec: 0.445; F1: 0.6141
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.3; Accu: 44.05; Pre: 0.9969; Rec: 0.4408; F1: 0.6113
# N: 75286
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.4; Accu: 19.37; Pre: 0.9996; Rec: 0.1858; F1: 0.3134
# N: 209563
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.4; Accu: 53.91; Pre: 0.992; Rec: 0.5389; F1: 0.6984
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.4; Accu: 53.85; Pre: 0.9974; Rec: 0.5391; F1: 0.6999
# N: 92319
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.5; Accu: 23.75; Pre: 0.9994; Rec: 0.2301; F1: 0.3741
# N: 245346
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.5; Accu: 63.11; Pre: 0.9931; Rec: 0.6319; F1: 0.7723
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.5; Accu: 62.77; Pre: 0.9978; Rec: 0.6284; F1: 0.7712
# N: 106495
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.6; Accu: 27.39; Pre: 0.9991; Rec: 0.267; F1: 0.4214
# N: 288035
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.6; Accu: 74.09; Pre: 0.994; Rec: 0.7429; F1: 0.8503
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.6; Accu: 74.11; Pre: 0.9981; Rec: 0.742; F1: 0.8512
# N: 120121
# seq_length: 30
# Comb-logits-based-Epoch: 95; tao=0.7; Accu: 30.9; Pre: 0.9987; Rec: 0.3026; F1: 0.4645
# N: 314108
# seq_length: 30
# Comb-statistic-based-Epoch: 95; tao=0.7; Accu: 80.8; Pre: 0.9937; Rec: 0.8112; F1: 0.8933
# seq_length: 30
# sample-wise-Epoch: 95; tao=0.7; Accu: 80.88; Pre: 0.9983; Rec: 0.8098; F1: 0.8942
# sample_shape: 38873
# num_samples_t 38873
# N: 26030ch
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.2; Accu: 6.696; Pre: 0.997; Rec: 0.05796; F1: 0.1096
# N: 84233
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.2; Accu: 21.67; Pre: 0.9851; Rec: 0.2122; F1: 0.3492
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.2; Accu: 21.48; Pre: 0.9978; Rec: 0.2138; F1: 0.3521
# N: 48582
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.3; Accu: 12.5; Pre: 0.9965; Rec: 0.1168; F1: 0.2091
# N: 133349
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.3; Accu: 34.3; Pre: 0.987; Rec: 0.3411; F1: 0.5069
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.3; Accu: 34.13; Pre: 0.9986; Rec: 0.3405; F1: 0.5079
# N: 73897
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.4; Accu: 19.01; Pre: 0.996; Rec: 0.1829; F1: 0.309
# N: 180242
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.4; Accu: 46.36; Pre: 0.9892; Rec: 0.4634; F1: 0.6312
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.4; Accu: 46.26; Pre: 0.999; Rec: 0.462; F1: 0.6318
# N: 96680
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.5; Accu: 24.87; Pre: 0.9954; Rec: 0.2424; F1: 0.3899
# N: 228760
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.5; Accu: 58.85; Pre: 0.991; Rec: 0.5898; F1: 0.7395
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.5; Accu: 59.13; Pre: 0.9992; Rec: 0.591; F1: 0.7427
# N: 116372
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.6; Accu: 29.93; Pre: 0.9949; Rec: 0.294; F1: 0.4538
# N: 256462
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.6; Accu: 65.97; Pre: 0.9912; Rec: 0.6623; F1: 0.794
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.6; Accu: 66.13; Pre: 0.9992; Rec: 0.6612; F1: 0.7958
# N: 134779
# seq_length: 30
# Comb-logits-based-Epoch: 96; tao=0.7; Accu: 34.67; Pre: 0.9943; Rec: 0.3422; F1: 0.5092
# N: 294124
# seq_length: 30
# Comb-statistic-based-Epoch: 96; tao=0.7; Accu: 75.66; Pre: 0.9904; Rec: 0.7616; F1: 0.861
# seq_length: 30
# sample-wise-Epoch: 96; tao=0.7; Accu: 76.75; Pre: 0.9982; Rec: 0.7685; F1: 0.8684
# sample_shape: 38873
# num_samples_t 38873
# N: 25560ch
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.2; Accu: 6.575; Pre: 0.9945; Rec: 0.05688; F1: 0.1076
# N: 94537
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.2; Accu: 24.32; Pre: 0.9807; Rec: 0.2405; F1: 0.3862
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.2; Accu: 24.17; Pre: 0.9975; Rec: 0.2408; F1: 0.388
# N: 41298
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.3; Accu: 10.62; Pre: 0.9946; Rec: 0.09797; F1: 0.1784
# N: 135706
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.3; Accu: 34.91; Pre: 0.9784; Rec: 0.3504; F1: 0.516
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.3; Accu: 35.19; Pre: 0.9974; Rec: 0.3516; F1: 0.5199
# N: 59934
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.4; Accu: 15.42; Pre: 0.9952; Rec: 0.1466; F1: 0.2555
# N: 165968
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.4; Accu: 42.69; Pre: 0.9798; Rec: 0.4302; F1: 0.5978
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.4; Accu: 43.07; Pre: 0.9961; Rec: 0.4313; F1: 0.602
# N: 79259
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.5; Accu: 20.39; Pre: 0.9955; Rec: 0.1969; F1: 0.3288
# N: 194385
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.5; Accu: 50.0; Pre: 0.9818; Rec: 0.5045; F1: 0.6665
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.5; Accu: 51.0; Pre: 0.9964; Rec: 0.511; F1: 0.6755
# N: 95024
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.6; Accu: 24.44; Pre: 0.9952; Rec: 0.2381; F1: 0.3843
# N: 230567
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.6; Accu: 59.31; Pre: 0.9842; Rec: 0.5987; F1: 0.7445
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.6; Accu: 60.6; Pre: 0.997; Rec: 0.6071; F1: 0.7546
# N: 109315
# seq_length: 30
# Comb-logits-based-Epoch: 97; tao=0.7; Accu: 28.12; Pre: 0.995; Rec: 0.2755; F1: 0.4315
# N: 264286
# seq_length: 30
# Comb-statistic-based-Epoch: 97; tao=0.7; Accu: 67.98; Pre: 0.9861; Rec: 0.6864; F1: 0.8094
# seq_length: 30
# sample-wise-Epoch: 97; tao=0.7; Accu: 68.59; Pre: 0.9973; Rec: 0.6872; F1: 0.8137
# sample_shape: 38873
# num_samples_t 38873
# N: 44692ch
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.2; Accu: 11.5; Pre: 0.9982; Rec: 0.1065; F1: 0.1924
# N: 111900
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.2; Accu: 28.78; Pre: 0.9912; Rec: 0.2834; F1: 0.4407
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.2; Accu: 28.03; Pre: 0.9997; Rec: 0.2791; F1: 0.4363
# N: 71095
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.3; Accu: 18.29; Pre: 0.9957; Rec: 0.1756; F1: 0.2986
# N: 166460
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.3; Accu: 42.82; Pre: 0.9875; Rec: 0.428; F1: 0.5972
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.3; Accu: 42.71; Pre: 0.999; Rec: 0.4264; F1: 0.5977
# N: 93409
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.4; Accu: 24.03; Pre: 0.9946; Rec: 0.2341; F1: 0.379
# N: 211131
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.4; Accu: 54.31; Pre: 0.9848; Rec: 0.547; F1: 0.7034
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.4; Accu: 54.47; Pre: 0.9971; Rec: 0.5454; F1: 0.7051
# N: 111148
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.5; Accu: 28.59; Pre: 0.9937; Rec: 0.2807; F1: 0.4377
# N: 258780
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.5; Accu: 66.57; Pre: 0.9858; Rec: 0.6721; F1: 0.7992
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.5; Accu: 66.77; Pre: 0.9972; Rec: 0.6689; F1: 0.8007
# N: 126266
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.6; Accu: 32.48; Pre: 0.9919; Rec: 0.3208; F1: 0.4848
# N: 307721
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.6; Accu: 79.16; Pre: 0.9879; Rec: 0.7993; F1: 0.8836
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.6; Accu: 80.37; Pre: 0.9977; Rec: 0.8052; F1: 0.8911
# N: 140488
# seq_length: 30
# Comb-logits-based-Epoch: 98; tao=0.7; Accu: 36.14; Pre: 0.9905; Rec: 0.3585; F1: 0.5265
# N: 324921
# seq_length: 30
# Comb-statistic-based-Epoch: 98; tao=0.7; Accu: 83.58; Pre: 0.9885; Rec: 0.844; F1: 0.9106
# seq_length: 30
# sample-wise-Epoch: 98; tao=0.7; Accu: 84.55; Pre: 0.9978; Rec: 0.8471; F1: 0.9163
# sample_shape: 38873
# num_samples_t 38873
# N: 28351ch
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.2; Accu: 7.293; Pre: 0.9844; Rec: 0.06484; F1: 0.1217
# N: 117681
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.2; Accu: 30.27; Pre: 0.9842; Rec: 0.3007; F1: 0.4606
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.2; Accu: 30.35; Pre: 0.9985; Rec: 0.3027; F1: 0.4646
# N: 48836
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.3; Accu: 12.56; Pre: 0.9858; Rec: 0.1187; F1: 0.212
# N: 167348
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.3; Accu: 43.05; Pre: 0.9876; Rec: 0.4303; F1: 0.5994
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.3; Accu: 43.06; Pre: 0.9989; Rec: 0.43; F1: 0.6012
# N: 69357
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.4; Accu: 17.84; Pre: 0.9858; Rec: 0.1728; F1: 0.2941
# N: 192648
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.4; Accu: 49.56; Pre: 0.988; Rec: 0.4966; F1: 0.661
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.4; Accu: 49.04; Pre: 0.9988; Rec: 0.49; F1: 0.6575
# N: 88315
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.5; Accu: 22.72; Pre: 0.9859; Rec: 0.2228; F1: 0.3634
# N: 226427
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.5; Accu: 58.24; Pre: 0.9882; Rec: 0.5853; F1: 0.7352
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.5; Accu: 57.85; Pre: 0.9978; Rec: 0.579; F1: 0.7328
# N: 104213
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.6; Accu: 26.81; Pre: 0.9862; Rec: 0.2646; F1: 0.4172
# N: 267145
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.6; Accu: 68.72; Pre: 0.9878; Rec: 0.6927; F1: 0.8143
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.6; Accu: 69.8; Pre: 0.9978; Rec: 0.699; F1: 0.8221
# N: 119761
# seq_length: 30
# Comb-logits-based-Epoch: 99; tao=0.7; Accu: 30.81; Pre: 0.987; Rec: 0.3053; F1: 0.4663
# N: 307798
# seq_length: 30
# Comb-statistic-based-Epoch: 99; tao=0.7; Accu: 79.18; Pre: 0.988; Rec: 0.7995; F1: 0.8838
# seq_length: 30
# sample-wise-Epoch: 99; tao=0.7; Accu: 81.17; Pre: 0.9977; Rec: 0.8132; F1: 0.896
# Main Terminating...
# Testing terminated | Training time=8028 s
