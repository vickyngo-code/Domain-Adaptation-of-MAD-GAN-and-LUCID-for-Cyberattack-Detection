# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "-1"

# %%
# !python3 RGAN.py --settings_file cicddos

# %%
import time

# %%
start = time.time()
# !python3 AD.py --settings_file cicddos_test

# %%
start = time.time()
# !python3 AD.py --settings_file swat_test
# Out:
# /home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ["[Errno 2] The file to load file system plugin from does not exist.: '/home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so'"]
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: cannot open shared object file: No such file or directory']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# WARNING:tensorflow:From /home/zvd0712/miniforge3/lib/python3.10/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Loading settings from ./experiments/settings/swat_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded swat_a from .csv
# Generated/loaded 997 samples from data-type swat_test
# Ready to run with settings:
#  	 settings_file
# swat_test 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# 1 	 kappa
# 15 	 latent_dim
# 0.5 	 weight
# 1 	 degree
# False 	 batch_mean
# False 	 learn_scale
# 0.1 	 learning_rate
# 500 	 batch_size
# 100 	 num_epochs
# 1 	 D_rounds
# 3 	 G_rounds
# 1 	 E_rounds
# True 	 shuffle
# False 	 eval_mul
# False 	 eval_an
# False 	 eval_single
# False 	 wrong_labels
# swat_test 	 identifier
# cicddos 	 sub_id
# False 	 dp
# 1e-05 	 l2norm_bound
# 1 	 batches_per_lot
# 1e-05 	 dp_sigma
# False 	 use_time
# 10 	 seq_step
# 6 	 num_generated_features
# Main Starting...
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# 2022-11-25 13:53:17.163436: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:357] MLIR V1 optimization pass is not enabled
# N: 5009
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.2; Accu: 50.14; Pre: 0.1102; Rec: 0.1118; F1: 0.111
# N: 7223
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.2; Accu: 72.3; Pre: 1.0; Rec: 0.005034; F1: 0.01002
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.2; Accu: 70.31; Pre: 1.0; Rec: 0.003367; F1: 0.006711
# N: 4927
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.3; Accu: 49.32; Pre: 0.1401; Rec: 0.1597; F1: 0.1492
# N: 7021
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.3; Accu: 70.28; Pre: 0.1619; Rec: 0.01618; F1: 0.02942
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.3; Accu: 70.31; Pre: 0.5556; Rec: 0.01684; F1: 0.03268
# N: 4890
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.4; Accu: 48.95; Pre: 0.1675; Rec: 0.21; F1: 0.1863
# N: 5087
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.4; Accu: 50.92; Pre: 0.2063; Rec: 0.2679; F1: 0.2331
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.4; Accu: 50.45; Pre: 0.2287; Rec: 0.2795; F1: 0.2515
# N: 4984
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.5; Accu: 49.89; Pre: 0.2428; Rec: 0.3776; F1: 0.2955
# N: 4996
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.5; Accu: 50.01; Pre: 0.2662; Rec: 0.4531; F1: 0.3354
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.5; Accu: 51.15; Pre: 0.3004; Rec: 0.4815; F1: 0.37
# N: 5483
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.6; Accu: 54.88; Pre: 0.3718; Rec: 0.9; F1: 0.5262
# N: 2748
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.6; Accu: 27.51; Pre: 0.1871; Rec: 0.4797; F1: 0.2692
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.6; Accu: 28.49; Pre: 0.2087; Rec: 0.5017; F1: 0.2948
# N: 4918
# seq_length: 30
# Comb-logits-based-Epoch: 0; tao=0.7; Accu: 49.23; Pre: 0.3446; Rec: 0.913; F1: 0.5003
# N: 3340
# seq_length: 30
# Comb-statistic-based-Epoch: 0; tao=0.7; Accu: 33.43; Pre: 0.2874; Rec: 0.9403; F1: 0.4402
# seq_length: 30
# sample-wise-Epoch: 0; tao=0.7; Accu: 34.1; Pre: 0.3035; Rec: 0.936; F1: 0.4584
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6165
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.2; Accu: 61.71; Pre: 0.1619; Rec: 0.0899; F1: 0.1156
# N: 6637
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.2; Accu: 66.44; Pre: 0.1871; Rec: 0.06149; F1: 0.09256
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.2; Accu: 66.7; Pre: 0.2464; Rec: 0.05724; F1: 0.0929
# N: 6060
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.3; Accu: 60.66; Pre: 0.3298; Rec: 0.4002; F1: 0.3616
# N: 6300
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.3; Accu: 63.06; Pre: 0.3201; Rec: 0.2909; F1: 0.3048
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.3; Accu: 63.89; Pre: 0.3811; Rec: 0.3401; F1: 0.3594
# N: 5807
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.4; Accu: 58.13; Pre: 0.3446; Rec: 0.5592; F1: 0.4264
# N: 6318
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.4; Accu: 63.24; Pre: 0.3642; Rec: 0.4297; F1: 0.3943
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.4; Accu: 63.29; Pre: 0.3951; Rec: 0.4377; F1: 0.4153
# N: 5005
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.5; Accu: 50.1; Pre: 0.2945; Rec: 0.5678; F1: 0.3878
# N: 6016
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.5; Accu: 60.22; Pre: 0.4043; Rec: 0.9065; F1: 0.5592
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.5; Accu: 61.18; Pre: 0.4312; Rec: 0.9495; F1: 0.5931
# N: 4983
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.6; Accu: 49.88; Pre: 0.2965; Rec: 0.5829; F1: 0.393
# N: 4137
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.6; Accu: 41.41; Pre: 0.3216; Rec: 0.9953; F1: 0.4861
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.6; Accu: 43.23; Pre: 0.3438; Rec: 0.9966; F1: 0.5112
# N: 4942
# seq_length: 30
# Comb-logits-based-Epoch: 1; tao=0.7; Accu: 49.47; Pre: 0.3; Rec: 0.6113; F1: 0.4025
# N: 4061
# seq_length: 30
# Comb-statistic-based-Epoch: 1; tao=0.7; Accu: 40.65; Pre: 0.3193; Rec: 1.0; F1: 0.484
# seq_length: 30
# sample-wise-Epoch: 1; tao=0.7; Accu: 42.83; Pre: 0.3426; Rec: 1.0; F1: 0.5103
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6287
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.2; Accu: 62.93; Pre: 0.2344; Rec: 0.1464; F1: 0.1802
# N: 7195
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.2; Accu: 72.02; Pre: 0.0; Rec: 0.0; F1: 0.0
# /home/zvd0712/miniforge3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.2; Accu: 70.21; Pre: 0.0; Rec: 0.0; F1: 0.0
# N: 6198
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.3; Accu: 62.04; Pre: 0.2451; Rec: 0.1748; F1: 0.204
# N: 5323
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.3; Accu: 53.28; Pre: 0.04576; Rec: 0.03416; F1: 0.03912
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.3; Accu: 47.94; Pre: 0.00885; Rec: 0.006734; F1: 0.007648
# N: 5886
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.4; Accu: 58.92; Pre: 0.2226; Rec: 0.1909; F1: 0.2056
# N: 4473
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.4; Accu: 44.77; Pre: 0.1501; Rec: 0.2111; F1: 0.1755
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.4; Accu: 44.73; Pre: 0.1727; Rec: 0.2256; F1: 0.1956
# N: 5792
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.5; Accu: 57.98; Pre: 0.246; Rec: 0.2467; F1: 0.2463
# N: 3872
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.5; Accu: 38.76; Pre: 0.1698; Rec: 0.3085; F1: 0.219
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.5; Accu: 38.52; Pre: 0.1877; Rec: 0.3199; F1: 0.2366
# N: 5832
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.6; Accu: 58.38; Pre: 0.3028; Rec: 0.3801; F1: 0.3371
# N: 3139
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.6; Accu: 31.42; Pre: 0.1778; Rec: 0.4038; F1: 0.2469
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.6; Accu: 32.0; Pre: 0.2; Rec: 0.4276; F1: 0.2725
# N: 6054
# seq_length: 30
# Comb-logits-based-Epoch: 2; tao=0.7; Accu: 60.6; Pre: 0.3585; Rec: 0.5261; F1: 0.4264
# N: 3781
# seq_length: 30
# Comb-statistic-based-Epoch: 2; tao=0.7; Accu: 37.85; Pre: 0.2609; Rec: 0.6728; F1: 0.376
# seq_length: 30
# sample-wise-Epoch: 2; tao=0.7; Accu: 38.62; Pre: 0.2785; Rec: 0.6667; F1: 0.3929
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7000
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.2; Accu: 70.07; Pre: 0.1505; Rec: 0.01618; F1: 0.02922
# N: 6152
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.2; Accu: 61.58; Pre: 0.3349; Rec: 0.3855; F1: 0.3584
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.2; Accu: 67.6; Pre: 0.4532; Rec: 0.4242; F1: 0.4383
# N: 6742
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.3; Accu: 67.49; Pre: 0.1611; Rec: 0.03991; F1: 0.06398
# N: 5968
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.3; Accu: 59.74; Pre: 0.3826; Rec: 0.7274; F1: 0.5015
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.3; Accu: 60.38; Pre: 0.4065; Rec: 0.7172; F1: 0.5189
# N: 6455
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.4; Accu: 64.61; Pre: 0.1869; Rec: 0.08091; F1: 0.1129
# N: 3686
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.4; Accu: 36.9; Pre: 0.2687; Rec: 0.7361; F1: 0.3937
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.4; Accu: 37.61; Pre: 0.287; Rec: 0.7374; F1: 0.4132
# N: 5253
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.5; Accu: 52.58; Pre: 0.1287; Rec: 0.1219; F1: 0.1252
# N: 3342
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.5; Accu: 33.45; Pre: 0.2624; Rec: 0.7677; F1: 0.3911
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.5; Accu: 34.3; Pre: 0.279; Rec: 0.7609; F1: 0.4083
# N: 4511
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.6; Accu: 45.16; Pre: 0.1206; Rec: 0.1543; F1: 0.1354
# N: 2942
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.6; Accu: 29.45; Pre: 0.26; Rec: 0.8314; F1: 0.3962
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.6; Accu: 30.39; Pre: 0.2767; Rec: 0.8283; F1: 0.4148
# N: 4305
# seq_length: 30
# Comb-logits-based-Epoch: 3; tao=0.7; Accu: 43.09; Pre: 0.1231; Rec: 0.1704; F1: 0.1429
# N: 2792
# seq_length: 30
# Comb-statistic-based-Epoch: 3; tao=0.7; Accu: 27.95; Pre: 0.2691; Rec: 0.9252; F1: 0.4169
# seq_length: 30
# sample-wise-Epoch: 3; tao=0.7; Accu: 27.78; Pre: 0.2817; Rec: 0.9192; F1: 0.4313
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6852
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.2; Accu: 68.59; Pre: 0.07801; Rec: 0.01187; F1: 0.0206
# N: 7423
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.2; Accu: 74.3; Pre: 0.6458; Rec: 0.1704; F1: 0.2697
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.2; Accu: 73.42; Pre: 0.7162; Rec: 0.1785; F1: 0.2857
# N: 7280
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.3; Accu: 72.87; Pre: 0.529; Rec: 0.233; F1: 0.3235
# N: 7296
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.3; Accu: 73.03; Pre: 0.5406; Rec: 0.2082; F1: 0.3006
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.3; Accu: 71.82; Pre: 0.5741; Rec: 0.2088; F1: 0.3062
# N: 7106
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.4; Accu: 71.13; Pre: 0.4735; Rec: 0.3312; F1: 0.3898
# N: 5447
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.4; Accu: 54.52; Pre: 0.2847; Rec: 0.4189; F1: 0.339
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.4; Accu: 54.66; Pre: 0.3077; Rec: 0.4175; F1: 0.3543
# N: 7239
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.5; Accu: 72.46; Pre: 0.5058; Rec: 0.4729; F1: 0.4888
# N: 5866
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.5; Accu: 58.72; Pre: 0.3747; Rec: 0.7224; F1: 0.4935
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.5; Accu: 59.28; Pre: 0.3962; Rec: 0.7003; F1: 0.5061
# N: 7173
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.6; Accu: 71.8; Pre: 0.4942; Rec: 0.5527; F1: 0.5218
# N: 5304
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.6; Accu: 53.09; Pre: 0.3437; Rec: 0.753; F1: 0.4719
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.6; Accu: 53.16; Pre: 0.3602; Rec: 0.7374; F1: 0.484
# N: 6540
# seq_length: 30
# Comb-logits-based-Epoch: 4; tao=0.7; Accu: 65.47; Pre: 0.4125; Rec: 0.5674; F1: 0.4777
# N: 5138
# seq_length: 30
# Comb-statistic-based-Epoch: 4; tao=0.7; Accu: 51.43; Pre: 0.3393; Rec: 0.7864; F1: 0.4741
# seq_length: 30
# sample-wise-Epoch: 4; tao=0.7; Accu: 51.86; Pre: 0.3573; Rec: 0.771; F1: 0.4883
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7249
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.2; Accu: 72.56; Pre: 0.6124; Rec: 0.03919; F1: 0.07367
# N: 6618
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.2; Accu: 66.25; Pre: 0.003361; Rec: 0.0007192; F1: 0.001185
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.2; Accu: 66.1; Pre: 0.0; Rec: 0.0; F1: 0.0
# N: 7240
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.3; Accu: 72.47; Pre: 0.5495; Rec: 0.06185; F1: 0.1112
# N: 6089
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.3; Accu: 60.95; Pre: 0.1095; Rec: 0.05645; F1: 0.0745
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.3; Accu: 57.77; Pre: 0.1026; Rec: 0.05387; F1: 0.07064
# N: 6227
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.4; Accu: 62.33; Pre: 0.1735; Rec: 0.09385; F1: 0.1218
# N: 5353
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.4; Accu: 53.58; Pre: 0.2972; Rec: 0.489; F1: 0.3697
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.4; Accu: 48.65; Pre: 0.2888; Rec: 0.4949; F1: 0.3648
# N: 5078
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.5; Accu: 50.83; Pre: 0.1244; Rec: 0.1269; F1: 0.1257
# N: 4169
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.5; Accu: 41.73; Pre: 0.2559; Rec: 0.5728; F1: 0.3537
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.5; Accu: 42.43; Pre: 0.2777; Rec: 0.5825; F1: 0.3761
# N: 4723
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.6; Accu: 47.28; Pre: 0.1706; Rec: 0.2316; F1: 0.1965
# N: 4223
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.6; Accu: 42.27; Pre: 0.2641; Rec: 0.6012; F1: 0.367
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.6; Accu: 42.63; Pre: 0.2828; Rec: 0.6027; F1: 0.3849
# N: 4947
# seq_length: 30
# Comb-logits-based-Epoch: 5; tao=0.7; Accu: 49.52; Pre: 0.2233; Rec: 0.3283; F1: 0.2658
# N: 4232
# seq_length: 30
# Comb-statistic-based-Epoch: 5; tao=0.7; Accu: 42.36; Pre: 0.2676; Rec: 0.6163; F1: 0.3732
# seq_length: 30
# sample-wise-Epoch: 5; tao=0.7; Accu: 42.63; Pre: 0.2868; Rec: 0.6229; F1: 0.3928
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6913
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.2; Accu: 69.2; Pre: 0.1105; Rec: 0.0151; F1: 0.02657
# N: 7132
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.2; Accu: 71.39; Pre: 0.0; Rec: 0.0; F1: 0.0
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.2; Accu: 69.61; Pre: 0.0; Rec: 0.0; F1: 0.0
# N: 6868
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.3; Accu: 68.75; Pre: 0.1972; Rec: 0.03991; F1: 0.06639
# N: 6379
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.3; Accu: 63.85; Pre: 0.08748; Rec: 0.03164; F1: 0.04647
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.3; Accu: 61.38; Pre: 0.02174; Rec: 0.006734; F1: 0.01028
# N: 6968
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.4; Accu: 69.75; Pre: 0.3324; Rec: 0.08594; F1: 0.1366
# N: 6012
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.4; Accu: 60.18; Pre: 0.2151; Rec: 0.1625; F1: 0.1852
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.4; Accu: 59.08; Pre: 0.2293; Rec: 0.1582; F1: 0.1873
# N: 6771
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.5; Accu: 67.78; Pre: 0.2849; Rec: 0.1043; F1: 0.1527
# N: 6130
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.5; Accu: 61.36; Pre: 0.273; Rec: 0.2334; F1: 0.2516
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.5; Accu: 60.38; Pre: 0.2924; Rec: 0.2323; F1: 0.2589
# N: 5364
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.6; Accu: 53.69; Pre: 0.1429; Rec: 0.1327; F1: 0.1376
# N: 5801
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.6; Accu: 58.07; Pre: 0.2538; Rec: 0.2611; F1: 0.2574
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.6; Accu: 57.47; Pre: 0.2787; Rec: 0.2694; F1: 0.274
# N: 4739
# seq_length: 30
# Comb-logits-based-Epoch: 6; tao=0.7; Accu: 47.44; Pre: 0.1387; Rec: 0.1704; F1: 0.1529
# N: 2978
# seq_length: 30
# Comb-statistic-based-Epoch: 6; tao=0.7; Accu: 29.81; Pre: 0.1545; Rec: 0.3402; F1: 0.2125
# seq_length: 30
# sample-wise-Epoch: 6; tao=0.7; Accu: 22.97; Pre: 0.1459; Rec: 0.3266; F1: 0.2017
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7782
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.2; Accu: 77.9; Pre: 0.7397; Rec: 0.3179; F1: 0.4447
# N: 7137
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.2; Accu: 71.44; Pre: 0.4355; Rec: 0.08738; F1: 0.1456
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.2; Accu: 71.51; Pre: 0.6512; Rec: 0.09428; F1: 0.1647
# N: 7369
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.3; Accu: 73.76; Pre: 0.5467; Rec: 0.3369; F1: 0.4169
# N: 6674
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.3; Accu: 66.81; Pre: 0.3156; Rec: 0.1647; F1: 0.2164
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.3; Accu: 65.4; Pre: 0.3235; Rec: 0.1481; F1: 0.2032
# N: 7081
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.4; Accu: 70.88; Pre: 0.4685; Rec: 0.3427; F1: 0.3958
# N: 6478
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.4; Accu: 64.84; Pre: 0.3508; Rec: 0.3089; F1: 0.3285
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.4; Accu: 63.69; Pre: 0.3651; Rec: 0.2963; F1: 0.3271
# N: 6731
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.5; Accu: 67.38; Pre: 0.4012; Rec: 0.3488; F1: 0.3731
# N: 6626
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.5; Accu: 66.33; Pre: 0.4299; Rec: 0.6426; F1: 0.5151
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.5; Accu: 65.6; Pre: 0.4442; Rec: 0.6162; F1: 0.5162
# N: 6180
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.6; Accu: 61.86; Pre: 0.3299; Rec: 0.3589; F1: 0.3438
# N: 6315
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.6; Accu: 63.21; Pre: 0.4011; Rec: 0.6523; F1: 0.4968
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.6; Accu: 62.99; Pre: 0.4204; Rec: 0.6397; F1: 0.5073
# N: 5006
# seq_length: 30
# Comb-logits-based-Epoch: 7; tao=0.7; Accu: 50.11; Pre: 0.2547; Rec: 0.4114; F1: 0.3146
# N: 4063
# seq_length: 30
# Comb-statistic-based-Epoch: 7; tao=0.7; Accu: 40.67; Pre: 0.2749; Rec: 0.6908; F1: 0.3933
# seq_length: 30
# sample-wise-Epoch: 7; tao=0.7; Accu: 43.33; Pre: 0.3012; Rec: 0.6835; F1: 0.4181
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6825
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.2; Accu: 68.32; Pre: 0.119; Rec: 0.02157; F1: 0.03653
# N: 4543
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.2; Accu: 45.48; Pre: 0.2836; Rec: 0.6282; F1: 0.3908
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.2; Accu: 44.03; Pre: 0.2905; Rec: 0.6094; F1: 0.3935
# N: 6807
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.3; Accu: 68.14; Pre: 0.1372; Rec: 0.02733; F1: 0.04558
# N: 3471
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.3; Accu: 34.74; Pre: 0.2537; Rec: 0.6922; F1: 0.3713
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.3; Accu: 35.41; Pre: 0.2732; Rec: 0.7037; F1: 0.3936
# N: 6891
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.4; Accu: 68.98; Pre: 0.2834; Rec: 0.07479; F1: 0.1183
# N: 3174
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.4; Accu: 31.77; Pre: 0.254; Rec: 0.749; F1: 0.3793
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.4; Accu: 33.2; Pre: 0.2742; Rec: 0.7542; F1: 0.4022
# N: 6760
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.5; Accu: 67.67; Pre: 0.3328; Rec: 0.1607; F1: 0.2168
# N: 3289
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.5; Accu: 32.92; Pre: 0.2667; Rec: 0.8055; F1: 0.4007
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.5; Accu: 33.3; Pre: 0.2772; Rec: 0.771; F1: 0.4078
# N: 7012
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.6; Accu: 70.19; Pre: 0.4441; Rec: 0.2816; F1: 0.3446
# N: 3157
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.6; Accu: 31.6; Pre: 0.2814; Rec: 0.9382; F1: 0.433
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.6; Accu: 33.4; Pre: 0.3012; Rec: 0.936; F1: 0.4557
# N: 6979
# seq_length: 30
# Comb-logits-based-Epoch: 8; tao=0.7; Accu: 69.86; Pre: 0.438; Rec: 0.292; F1: 0.3504
# N: 2930
# seq_length: 30
# Comb-statistic-based-Epoch: 8; tao=0.7; Accu: 29.33; Pre: 0.2821; Rec: 0.996; F1: 0.4397
# seq_length: 30
# sample-wise-Epoch: 8; tao=0.7; Accu: 31.29; Pre: 0.3024; Rec: 1.0; F1: 0.4644
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6647
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.2; Accu: 66.54; Pre: 0.203; Rec: 0.06904; F1: 0.103
# N: 6251
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.2; Accu: 62.57; Pre: 0.0; Rec: 0.0; F1: 0.0
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.2; Accu: 59.18; Pre: 0.008929; Rec: 0.003367; F1: 0.00489
# N: 6314
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.3; Accu: 63.2; Pre: 0.1702; Rec: 0.08306; F1: 0.1116
# N: 5989
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.3; Accu: 59.95; Pre: 0.01433; Rec: 0.006472; F1: 0.008918
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.3; Accu: 58.27; Pre: 0.024; Rec: 0.0101; F1: 0.01422
# N: 6038
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.4; Accu: 60.44; Pre: 0.281; Rec: 0.27; F1: 0.2754
# N: 4733
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.4; Accu: 47.38; Pre: 0.07133; Rec: 0.07407; F1: 0.07268
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.4; Accu: 46.24; Pre: 0.08651; Rec: 0.08418; F1: 0.08532
# N: 5950
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.5; Accu: 59.56; Pre: 0.2913; Rec: 0.3161; F1: 0.3032
# N: 4048
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.5; Accu: 40.52; Pre: 0.1821; Rec: 0.3254; F1: 0.2335
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.5; Accu: 40.12; Pre: 0.2012; Rec: 0.3401; F1: 0.2528
# N: 6058
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.6; Accu: 60.64; Pre: 0.3345; Rec: 0.4182; F1: 0.3717
# N: 3542
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.6; Accu: 35.46; Pre: 0.173; Rec: 0.3488; F1: 0.2313
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.6; Accu: 35.11; Pre: 0.1875; Rec: 0.3535; F1: 0.245
# N: 6040
# seq_length: 30
# Comb-logits-based-Epoch: 9; tao=0.7; Accu: 60.46; Pre: 0.3515; Rec: 0.4973; F1: 0.4119
# N: 3824
# seq_length: 30
# Comb-statistic-based-Epoch: 9; tao=0.7; Accu: 38.28; Pre: 0.2385; Rec: 0.5552; F1: 0.3337
# seq_length: 30
# sample-wise-Epoch: 9; tao=0.7; Accu: 39.12; Pre: 0.2601; Rec: 0.5657; F1: 0.3563
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7728
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.2; Accu: 77.36; Pre: 0.6771; Rec: 0.3567; F1: 0.4673
# N: 7226
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.2; Accu: 72.33; Pre: 0.5084; Rec: 0.1845; F1: 0.2707
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.2; Accu: 71.11; Pre: 0.5437; Rec: 0.1886; F1: 0.28
# N: 6181
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.3; Accu: 61.87; Pre: 0.3743; Rec: 0.5505; F1: 0.4456
# N: 7288
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.3; Accu: 72.95; Pre: 0.5254; Rec: 0.2941; F1: 0.3771
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.3; Accu: 72.42; Pre: 0.5821; Rec: 0.2626; F1: 0.3619
# N: 5396
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.4; Accu: 54.01; Pre: 0.327; Rec: 0.616; F1: 0.4272
# N: 6417
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.4; Accu: 64.23; Pre: 0.3553; Rec: 0.3495; F1: 0.3524
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.4; Accu: 64.19; Pre: 0.3889; Rec: 0.3535; F1: 0.3704
# N: 4602
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.5; Accu: 46.07; Pre: 0.2847; Rec: 0.6196; F1: 0.3901
# N: 6260
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.5; Accu: 62.66; Pre: 0.3635; Rec: 0.4545; F1: 0.404
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.5; Accu: 63.29; Pre: 0.4034; Rec: 0.4848; F1: 0.4404
# N: 4351
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.6; Accu: 43.55; Pre: 0.2741; Rec: 0.6235; F1: 0.3808
# N: 4543
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.6; Accu: 45.48; Pre: 0.3342; Rec: 0.9662; F1: 0.4966
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.6; Accu: 46.34; Pre: 0.3538; Rec: 0.9697; F1: 0.5185
# N: 4148
# seq_length: 30
# Comb-logits-based-Epoch: 10; tao=0.7; Accu: 41.52; Pre: 0.2691; Rec: 0.6411; F1: 0.379
# N: 3883
# seq_length: 30
# Comb-statistic-based-Epoch: 10; tao=0.7; Accu: 38.87; Pre: 0.3109; Rec: 0.9835; F1: 0.4725
# seq_length: 30
# sample-wise-Epoch: 10; tao=0.7; Accu: 40.92; Pre: 0.3337; Rec: 0.9865; F1: 0.4987
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6377
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.2; Accu: 63.83; Pre: 0.3485; Rec: 0.3441; F1: 0.3463
# N: 6288
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.2; Accu: 62.94; Pre: 0.1295; Rec: 0.05789; F1: 0.08002
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.2; Accu: 60.18; Pre: 0.1377; Rec: 0.06397; F1: 0.08736
# N: 6292
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.3; Accu: 62.98; Pre: 0.3406; Rec: 0.3524; F1: 0.3464
# N: 5846
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.3; Accu: 58.52; Pre: 0.1031; Rec: 0.06365; F1: 0.0787
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.3; Accu: 57.37; Pre: 0.1235; Rec: 0.07071; F1: 0.08994
# N: 6239
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.4; Accu: 62.45; Pre: 0.343; Rec: 0.3812; F1: 0.3611
# N: 5541
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.4; Accu: 55.47; Pre: 0.1433; Rec: 0.1205; F1: 0.1309
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.4; Accu: 54.66; Pre: 0.1616; Rec: 0.1246; F1: 0.1407
# N: 6089
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.5; Accu: 60.95; Pre: 0.3421; Rec: 0.4362; F1: 0.3834
# N: 5086
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.5; Accu: 50.91; Pre: 0.1761; Rec: 0.2075; F1: 0.1905
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.5; Accu: 49.85; Pre: 0.1798; Rec: 0.1919; F1: 0.1857
# N: 5770
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.6; Accu: 57.76; Pre: 0.3412; Rec: 0.5559; F1: 0.4229
# N: 4557
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.6; Accu: 45.62; Pre: 0.2574; Rec: 0.5059; F1: 0.3412
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.6; Accu: 45.64; Pre: 0.2693; Rec: 0.4815; F1: 0.3454
# N: 5174
# seq_length: 30
# Comb-logits-based-Epoch: 11; tao=0.7; Accu: 51.79; Pre: 0.3102; Rec: 0.598; F1: 0.4085
# N: 2590
# seq_length: 30
# Comb-statistic-based-Epoch: 11; tao=0.7; Accu: 25.93; Pre: 0.2386; Rec: 0.758; F1: 0.3629
# seq_length: 30
# sample-wise-Epoch: 11; tao=0.7; Accu: 26.78; Pre: 0.2576; Rec: 0.7744; F1: 0.3866
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6263
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.2; Accu: 62.69; Pre: 0.2972; Rec: 0.2492; F1: 0.2711
# N: 7449
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.2; Accu: 74.56; Pre: 0.9167; Rec: 0.09493; F1: 0.172
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.2; Accu: 73.42; Pre: 1.0; Rec: 0.1077; F1: 0.1945
# N: 6252
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.3; Accu: 62.58; Pre: 0.3722; Rec: 0.5009; F1: 0.427
# N: 6967
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.3; Accu: 69.74; Pre: 0.3745; Rec: 0.1298; F1: 0.1928
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.3; Accu: 69.41; Pre: 0.4535; Rec: 0.1313; F1: 0.2037
# N: 5955
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.4; Accu: 59.61; Pre: 0.3767; Rec: 0.6886; F1: 0.487
# N: 6417
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.4; Accu: 64.23; Pre: 0.2432; Rec: 0.1348; F1: 0.1735
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.4; Accu: 63.19; Pre: 0.2727; Rec: 0.1414; F1: 0.1863
# N: 5850
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.5; Accu: 58.56; Pre: 0.3702; Rec: 0.6965; F1: 0.4834
# N: 6341
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.5; Accu: 63.47; Pre: 0.2976; Rec: 0.2294; F1: 0.2591
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.5; Accu: 62.79; Pre: 0.3255; Rec: 0.2323; F1: 0.2711
# N: 5782
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.6; Accu: 57.88; Pre: 0.3673; Rec: 0.7098; F1: 0.4841
# N: 5159
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.6; Accu: 51.64; Pre: 0.3459; Rec: 0.8274; F1: 0.4879
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.6; Accu: 52.16; Pre: 0.3645; Rec: 0.8148; F1: 0.5036
# N: 5576
# seq_length: 30
# Comb-logits-based-Epoch: 12; tao=0.7; Accu: 55.82; Pre: 0.3571; Rec: 0.7335; F1: 0.4803
# N: 4515
# seq_length: 30
# Comb-statistic-based-Epoch: 12; tao=0.7; Accu: 45.2; Pre: 0.3259; Rec: 0.9065; F1: 0.4794
# seq_length: 30
# sample-wise-Epoch: 12; tao=0.7; Accu: 40.62; Pre: 0.3254; Rec: 0.9259; F1: 0.4816
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7035
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.2; Accu: 70.42; Pre: 0.1282; Rec: 0.01079; F1: 0.0199
# N: 6017
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.2; Accu: 60.23; Pre: 0.3101; Rec: 0.3499; F1: 0.3288
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.2; Accu: 62.19; Pre: 0.3795; Rec: 0.4242; F1: 0.4006
# N: 6764
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.3; Accu: 67.71; Pre: 0.1518; Rec: 0.03488; F1: 0.05673
# N: 6242
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.3; Accu: 62.48; Pre: 0.3805; Rec: 0.5534; F1: 0.4509
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.3; Accu: 62.89; Pre: 0.4112; Rec: 0.569; F1: 0.4774
# N: 6760
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.4; Accu: 67.67; Pre: 0.2034; Rec: 0.05538; F1: 0.08705
# N: 6153
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.4; Accu: 61.59; Pre: 0.3828; Rec: 0.6199; F1: 0.4733
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.4; Accu: 61.48; Pre: 0.4027; Rec: 0.6061; F1: 0.4839
# N: 6624
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.5; Accu: 66.31; Pre: 0.1831; Rec: 0.06077; F1: 0.09125
# N: 5688
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.5; Accu: 56.94; Pre: 0.3513; Rec: 0.6462; F1: 0.4552
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.5; Accu: 56.77; Pre: 0.3686; Rec: 0.633; F1: 0.4659
# N: 6307
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.6; Accu: 63.13; Pre: 0.1498; Rec: 0.0694; F1: 0.09486
# N: 5598
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.6; Accu: 56.04; Pre: 0.3501; Rec: 0.6764; F1: 0.4614
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.6; Accu: 56.97; Pre: 0.3745; Rec: 0.6633; F1: 0.4787
# N: 6248
# seq_length: 30
# Comb-logits-based-Epoch: 13; tao=0.7; Accu: 62.54; Pre: 0.191; Rec: 0.1068; F1: 0.137
# N: 5223
# seq_length: 30
# Comb-statistic-based-Epoch: 13; tao=0.7; Accu: 52.28; Pre: 0.341; Rec: 0.7659; F1: 0.4719
# seq_length: 30
# sample-wise-Epoch: 13; tao=0.7; Accu: 53.86; Pre: 0.3644; Rec: 0.7374; F1: 0.4878
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7198
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.2; Accu: 72.05; Pre: 0.1765; Rec: 0.001079; F1: 0.002144
# N: 6917
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.2; Accu: 69.24; Pre: 0.1907; Rec: 0.03236; F1: 0.05533
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.2; Accu: 67.1; Pre: 0.2075; Rec: 0.03704; F1: 0.06286
# N: 7135
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.3; Accu: 71.42; Pre: 0.06977; Rec: 0.002157; F1: 0.004186
# N: 6529
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.3; Accu: 65.36; Pre: 0.2715; Rec: 0.1453; F1: 0.1893
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.3; Accu: 63.49; Pre: 0.2721; Rec: 0.1347; F1: 0.1802
# N: 6873
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.4; Accu: 68.8; Pre: 0.05789; Rec: 0.007911; F1: 0.01392
# N: 6393
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.4; Accu: 63.99; Pre: 0.3412; Rec: 0.3154; F1: 0.3278
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.4; Accu: 62.89; Pre: 0.3569; Rec: 0.3064; F1: 0.3297
# N: 6670
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.5; Accu: 66.77; Pre: 0.1252; Rec: 0.03236; F1: 0.05143
# N: 6126
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.5; Accu: 61.32; Pre: 0.3114; Rec: 0.3215; F1: 0.3163
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.5; Accu: 60.48; Pre: 0.3298; Rec: 0.3165; F1: 0.323
# N: 6492
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.6; Accu: 64.98; Pre: 0.1556; Rec: 0.05825; F1: 0.08477
# N: 6031
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.6; Accu: 60.37; Pre: 0.3025; Rec: 0.3243; F1: 0.313
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.6; Accu: 59.98; Pre: 0.3277; Rec: 0.3266; F1: 0.3272
# N: 6413
# seq_length: 30
# Comb-logits-based-Epoch: 14; tao=0.7; Accu: 64.19; Pre: 0.2091; Rec: 0.1028; F1: 0.1379
# N: 5598
# seq_length: 30
# Comb-statistic-based-Epoch: 14; tao=0.7; Accu: 56.04; Pre: 0.2746; Rec: 0.3528; F1: 0.3088
# seq_length: 30
# sample-wise-Epoch: 14; tao=0.7; Accu: 57.57; Pre: 0.3114; Rec: 0.3502; F1: 0.3296
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6016
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.2; Accu: 60.22; Pre: 0.2694; Rec: 0.2506; F1: 0.2597
# N: 6538
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.2; Accu: 65.45; Pre: 0.2531; Rec: 0.1237; F1: 0.1662
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.2; Accu: 64.49; Pre: 0.295; Rec: 0.138; F1: 0.1881
# N: 6330
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.3; Accu: 63.36; Pre: 0.3633; Rec: 0.42; F1: 0.3896
# N: 5340
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.3; Accu: 53.45; Pre: 0.2927; Rec: 0.4746; F1: 0.3621
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.3; Accu: 52.26; Pre: 0.305; Rec: 0.4714; F1: 0.3704
# N: 6413
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.4; Accu: 64.19; Pre: 0.3809; Rec: 0.4577; F1: 0.4158
# N: 4931
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.4; Accu: 49.36; Pre: 0.2826; Rec: 0.5325; F1: 0.3693
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.4; Accu: 49.85; Pre: 0.3067; Rec: 0.5421; F1: 0.3917
# N: 6326
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.5; Accu: 63.32; Pre: 0.3788; Rec: 0.4962; F1: 0.4296
# N: 3752
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.5; Accu: 37.56; Pre: 0.2841; Rec: 0.8177; F1: 0.4217
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.5; Accu: 38.72; Pre: 0.3052; Rec: 0.8283; F1: 0.4461
# N: 6103
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.6; Accu: 61.09; Pre: 0.3598; Rec: 0.5102; F1: 0.422
# N: 4137
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.6; Accu: 41.41; Pre: 0.3212; Rec: 0.9924; F1: 0.4854
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.6; Accu: 43.23; Pre: 0.3434; Rec: 0.9933; F1: 0.5104
# N: 6079
# seq_length: 30
# Comb-logits-based-Epoch: 15; tao=0.7; Accu: 60.85; Pre: 0.3582; Rec: 0.5131; F1: 0.4219
# N: 3959
# seq_length: 30
# Comb-statistic-based-Epoch: 15; tao=0.7; Accu: 39.63; Pre: 0.3154; Rec: 0.9982; F1: 0.4793
# seq_length: 30
# sample-wise-Epoch: 15; tao=0.7; Accu: 42.73; Pre: 0.3418; Rec: 0.9966; F1: 0.509
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6812
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.2; Accu: 68.19; Pre: 0.3217; Rec: 0.1287; F1: 0.1839
# N: 6219
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.2; Accu: 62.25; Pre: 0.3361; Rec: 0.365; F1: 0.3499
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.2; Accu: 61.99; Pre: 0.3642; Rec: 0.3704; F1: 0.3673
# N: 6664
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.3; Accu: 66.71; Pre: 0.3112; Rec: 0.1615; F1: 0.2126
# N: 5131
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.3; Accu: 51.36; Pre: 0.2536; Rec: 0.3844; F1: 0.3056
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.3; Accu: 51.86; Pre: 0.273; Rec: 0.3704; F1: 0.3143
# N: 6204
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.4; Accu: 62.1; Pre: 0.3535; Rec: 0.4362; F1: 0.3905
# N: 3971
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.4; Accu: 39.75; Pre: 0.2273; Rec: 0.4854; F1: 0.3097
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.4; Accu: 46.24; Pre: 0.2741; Rec: 0.4882; F1: 0.3511
# N: 5256
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.5; Accu: 52.61; Pre: 0.289; Rec: 0.4811; F1: 0.3611
# N: 2955
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.5; Accu: 29.58; Pre: 0.2678; Rec: 0.8821; F1: 0.4109
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.5; Accu: 30.79; Pre: 0.2848; Rec: 0.8754; F1: 0.4298
# N: 5166
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.6; Accu: 51.71; Pre: 0.287; Rec: 0.4948; F1: 0.3633
# N: 2739
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.6; Accu: 27.42; Pre: 0.2725; Rec: 0.9626; F1: 0.4248
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.6; Accu: 29.39; Pre: 0.2926; Rec: 0.9663; F1: 0.4491
# N: 5062
# seq_length: 30
# Comb-logits-based-Epoch: 16; tao=0.7; Accu: 50.67; Pre: 0.2926; Rec: 0.5444; F1: 0.3806
# N: 2780
# seq_length: 30
# Comb-statistic-based-Epoch: 16; tao=0.7; Accu: 27.83; Pre: 0.2767; Rec: 0.9871; F1: 0.4323
# seq_length: 30
# sample-wise-Epoch: 16; tao=0.7; Accu: 29.69; Pre: 0.296; Rec: 0.9865; F1: 0.4553
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6038
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.2; Accu: 60.44; Pre: 0.1694; Rec: 0.1079; F1: 0.1318
# N: 7085
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.2; Accu: 70.92; Pre: 0.4197; Rec: 0.1165; F1: 0.1824
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.2; Accu: 72.02; Pre: 0.6552; Rec: 0.1279; F1: 0.2141
# N: 5332
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.3; Accu: 53.37; Pre: 0.1756; Rec: 0.1827; F1: 0.1791
# N: 6814
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.3; Accu: 68.21; Pre: 0.3449; Rec: 0.1579; F1: 0.2166
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.3; Accu: 66.5; Pre: 0.352; Rec: 0.1481; F1: 0.2085
# N: 5086
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.4; Accu: 50.91; Pre: 0.2376; Rec: 0.3456; F1: 0.2816
# N: 6871
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.4; Accu: 68.78; Pre: 0.3817; Rec: 0.196; F1: 0.259
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.4; Accu: 67.3; Pre: 0.3972; Rec: 0.1886; F1: 0.2557
# N: 5105
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.5; Accu: 51.1; Pre: 0.2489; Rec: 0.375; F1: 0.2992
# N: 5102
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.5; Accu: 51.07; Pre: 0.2114; Rec: 0.2776; F1: 0.24
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.5; Accu: 49.95; Pre: 0.221; Rec: 0.2694; F1: 0.2428
# N: 5151
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.6; Accu: 51.56; Pre: 0.2589; Rec: 0.3973; F1: 0.3135
# N: 4751
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.6; Accu: 47.56; Pre: 0.2771; Rec: 0.5494; F1: 0.3684
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.6; Accu: 47.84; Pre: 0.2954; Rec: 0.5421; F1: 0.3824
# N: 5150
# seq_length: 30
# Comb-logits-based-Epoch: 17; tao=0.7; Accu: 51.55; Pre: 0.261; Rec: 0.4042; F1: 0.3172
# N: 4798
# seq_length: 30
# Comb-statistic-based-Epoch: 17; tao=0.7; Accu: 48.03; Pre: 0.2882; Rec: 0.5897; F1: 0.3872
# seq_length: 30
# sample-wise-Epoch: 17; tao=0.7; Accu: 47.84; Pre: 0.302; Rec: 0.5724; F1: 0.3953
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6758
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.2; Accu: 67.65; Pre: 0.3183; Rec: 0.142; F1: 0.1964
# N: 7211
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.2; Accu: 72.18; Pre: 0.625; Rec: 0.001798; F1: 0.003586
# /home/zvd0712/miniforge3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.2; Accu: 70.21; Pre: 0.0; Rec: 0.0; F1: 0.0
# N: 6530
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.3; Accu: 65.37; Pre: 0.3795; Rec: 0.3844; F1: 0.3819
# N: 6723
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.3; Accu: 67.3; Pre: 0.08103; Rec: 0.0169; F1: 0.02797
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.3; Accu: 65.5; Pre: 0.08772; Rec: 0.01684; F1: 0.02825
# N: 5511
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.4; Accu: 55.17; Pre: 0.3568; Rec: 0.7605; F1: 0.4857
# N: 5368
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.4; Accu: 53.73; Pre: 0.1554; Rec: 0.1492; F1: 0.1522
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.4; Accu: 48.14; Pre: 0.1429; Rec: 0.1481; F1: 0.1455
# N: 3932
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.5; Accu: 39.36; Pre: 0.2974; Rec: 0.8648; F1: 0.4426
# N: 4649
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.5; Accu: 46.54; Pre: 0.3254; Rec: 0.858; F1: 0.4719
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.5; Accu: 47.34; Pre: 0.3451; Rec: 0.8552; F1: 0.4918
# N: 3992
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.6; Accu: 39.96; Pre: 0.3051; Rec: 0.9058; F1: 0.4565
# N: 3438
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.6; Accu: 34.41; Pre: 0.2906; Rec: 0.9407; F1: 0.444
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.6; Accu: 35.21; Pre: 0.308; Rec: 0.9428; F1: 0.4643
# N: 3958
# seq_length: 30
# Comb-logits-based-Epoch: 18; tao=0.7; Accu: 39.62; Pre: 0.3058; Rec: 0.9205; F1: 0.4591
# N: 3262
# seq_length: 30
# Comb-statistic-based-Epoch: 18; tao=0.7; Accu: 32.65; Pre: 0.2872; Rec: 0.9579; F1: 0.4419
# seq_length: 30
# sample-wise-Epoch: 18; tao=0.7; Accu: 34.5; Pre: 0.3069; Rec: 0.9529; F1: 0.4643
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6907
# seq_length: 30
# Comb-logits-based-Epoch: 19; tao=0.2; Accu: 69.14; Pre: 0.07102; Rec: 0.00899; F1: 0.01596
# N: 5627
# seq_length: 30
# Comb-statistic-based-Epoch: 19; tao=0.2; Accu: 56.33; Pre: 0.2702; Rec: 0.3344; F1: 0.2989
# seq_length: 30
# sample-wise-Epoch: 19; tao=0.2; Accu: 56.77; Pre: 0.3107; Rec: 0.3704; F1: 0.3379
# N: 6577
# seq_length: 30
# ...
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6861
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.2; Accu: 68.68; Pre: 0.07561; Rec: 0.01115; F1: 0.01943
# N: 5157
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.2; Accu: 51.62; Pre: 0.1831; Rec: 0.2132; F1: 0.197
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.2; Accu: 53.46; Pre: 0.2226; Rec: 0.2256; F1: 0.2241
# N: 6477
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.3; Accu: 64.83; Pre: 0.1211; Rec: 0.04207; F1: 0.06245
# N: 5142
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.3; Accu: 51.47; Pre: 0.2469; Rec: 0.3625; F1: 0.2937
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.3; Accu: 51.76; Pre: 0.2723; Rec: 0.3704; F1: 0.3138
# N: 6223
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.4; Accu: 62.29; Pre: 0.1508; Rec: 0.07659; F1: 0.1016
# N: 4678
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.4; Accu: 46.83; Pre: 0.2372; Rec: 0.4106; F1: 0.3007
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.4; Accu: 48.75; Pre: 0.2704; Rec: 0.4242; F1: 0.3303
# N: 5910
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.5; Accu: 59.16; Pre: 0.1849; Rec: 0.137; F1: 0.1574
# N: 4142
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.5; Accu: 41.46; Pre: 0.2243; Rec: 0.4488; F1: 0.2991
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.5; Accu: 40.32; Pre: 0.2395; Rec: 0.4613; F1: 0.3153
# N: 5960
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.6; Accu: 59.66; Pre: 0.2359; Rec: 0.2006; F1: 0.2169
# N: 3743
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.6; Accu: 37.47; Pre: 0.227; Rec: 0.5182; F1: 0.3157
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.6; Accu: 37.41; Pre: 0.2504; Rec: 0.5522; F1: 0.3445
# N: 5893
# seq_length: 30
# Comb-logits-based-Epoch: 41; tao=0.7; Accu: 58.99; Pre: 0.2498; Rec: 0.2362; F1: 0.2428
# N: 3530
# seq_length: 30
# Comb-statistic-based-Epoch: 41; tao=0.7; Accu: 35.34; Pre: 0.2504; Rec: 0.6638; F1: 0.3637
# seq_length: 30
# sample-wise-Epoch: 41; tao=0.7; Accu: 38.92; Pre: 0.2821; Rec: 0.6801; F1: 0.3988
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 5025
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.2; Accu: 50.3; Pre: 0.1638; Rec: 0.1913; F1: 0.1765
# N: 6460
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.2; Accu: 64.66; Pre: 0.3278; Rec: 0.2564; F1: 0.2877
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.2; Accu: 61.38; Pre: 0.3254; Rec: 0.2761; F1: 0.2987
# N: 4630
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.3; Accu: 46.35; Pre: 0.1825; Rec: 0.2665; F1: 0.2166
# N: 6362
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.3; Accu: 63.68; Pre: 0.3662; Rec: 0.4168; F1: 0.3898
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.3; Accu: 63.69; Pre: 0.3955; Rec: 0.4141; F1: 0.4046
# N: 5131
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.4; Accu: 51.36; Pre: 0.2938; Rec: 0.5325; F1: 0.3787
# N: 5138
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.4; Accu: 51.43; Pre: 0.2717; Rec: 0.443; F1: 0.3368
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.4; Accu: 50.35; Pre: 0.2829; Rec: 0.4343; F1: 0.3426
# N: 4432
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.5; Accu: 44.36; Pre: 0.2674; Rec: 0.5739; F1: 0.3648
# N: 3487
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.5; Accu: 34.9; Pre: 0.2844; Rec: 0.8828; F1: 0.4302
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.5; Accu: 36.01; Pre: 0.3042; Rec: 0.8923; F1: 0.4538
# N: 4236
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.6; Accu: 42.4; Pre: 0.2592; Rec: 0.5753; F1: 0.3574
# N: 3107
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.6; Accu: 31.1; Pre: 0.2878; Rec: 1.0; F1: 0.4469
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.6; Accu: 33.3; Pre: 0.3087; Rec: 1.0; F1: 0.4718
# N: 3952
# seq_length: 30
# Comb-logits-based-Epoch: 42; tao=0.7; Accu: 39.56; Pre: 0.2486; Rec: 0.5789; F1: 0.3478
# N: 2781
# seq_length: 30
# Comb-statistic-based-Epoch: 42; tao=0.7; Accu: 27.84; Pre: 0.2784; Rec: 1.0; F1: 0.4355
# seq_length: 30
# sample-wise-Epoch: 42; tao=0.7; Accu: 29.79; Pre: 0.2979; Rec: 1.0; F1: 0.459
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7308
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.2; Accu: 73.15; Pre: 0.7513; Rec: 0.05322; F1: 0.0994
# N: 5641
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.2; Accu: 56.47; Pre: 0.2139; Rec: 0.2107; F1: 0.2123
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.2; Accu: 53.76; Pre: 0.223; Rec: 0.2222; F1: 0.2226
# N: 7386
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.3; Accu: 73.93; Pre: 0.7626; Rec: 0.09241; F1: 0.1648
# N: 5291
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.3; Accu: 52.96; Pre: 0.2249; Rec: 0.2819; F1: 0.2502
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.3; Accu: 52.16; Pre: 0.2384; Rec: 0.2761; F1: 0.2559
# N: 7295
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.4; Accu: 73.02; Pre: 0.5587; Rec: 0.1471; F1: 0.2328
# N: 5334
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.4; Accu: 53.39; Pre: 0.2657; Rec: 0.3822; F1: 0.3135
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.4; Accu: 53.16; Pre: 0.2864; Rec: 0.3838; F1: 0.3281
# N: 7124
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.5; Accu: 71.31; Pre: 0.456; Rec: 0.1586; F1: 0.2353
# N: 5498
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.5; Accu: 55.04; Pre: 0.2974; Rec: 0.4516; F1: 0.3587
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.5; Accu: 54.86; Pre: 0.3183; Rec: 0.4512; F1: 0.3733
# N: 7076
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.6; Accu: 70.83; Pre: 0.4362; Rec: 0.1636; F1: 0.238
# N: 5404
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.6; Accu: 54.09; Pre: 0.3119; Rec: 0.5379; F1: 0.3948
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.6; Accu: 54.46; Pre: 0.3368; Rec: 0.5455; F1: 0.4165
# N: 7020
# seq_length: 30
# Comb-logits-based-Epoch: 43; tao=0.7; Accu: 70.27; Pre: 0.4217; Rec: 0.183; F1: 0.2553
# N: 4945
# seq_length: 30
# Comb-statistic-based-Epoch: 43; tao=0.7; Accu: 49.5; Pre: 0.2873; Rec: 0.5498; F1: 0.3774
# seq_length: 30
# sample-wise-Epoch: 43; tao=0.7; Accu: 50.15; Pre: 0.3099; Rec: 0.5488; F1: 0.3961
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6557
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.2; Accu: 65.64; Pre: 0.04469; Rec: 0.01151; F1: 0.0183
# N: 6363
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.2; Accu: 63.69; Pre: 0.3698; Rec: 0.4322; F1: 0.3986
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.2; Accu: 60.68; Pre: 0.3623; Rec: 0.4209; F1: 0.3894
# N: 6279
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.3; Accu: 62.85; Pre: 0.03777; Rec: 0.01366; F1: 0.02007
# N: 5912
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.3; Accu: 59.18; Pre: 0.3434; Rec: 0.5113; F1: 0.4109
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.3; Accu: 58.58; Pre: 0.3578; Rec: 0.4916; F1: 0.4142
# N: 5985
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.4; Accu: 59.91; Pre: 0.03985; Rec: 0.01906; F1: 0.02578
# N: 4832
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.4; Accu: 48.37; Pre: 0.2852; Rec: 0.5674; F1: 0.3796
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.4; Accu: 48.65; Pre: 0.3042; Rec: 0.5623; F1: 0.3948
# N: 5745
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.5; Accu: 57.51; Pre: 0.03904; Rec: 0.02229; F1: 0.02838
# N: 4575
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.5; Accu: 45.8; Pre: 0.2754; Rec: 0.5807; F1: 0.3736
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.5; Accu: 45.94; Pre: 0.2935; Rec: 0.5791; F1: 0.3896
# N: 5094
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.6; Accu: 50.99; Pre: 0.05019; Rec: 0.04243; F1: 0.04599
# N: 3609
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.6; Accu: 36.13; Pre: 0.2378; Rec: 0.5868; F1: 0.3384
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.6; Accu: 36.21; Pre: 0.2526; Rec: 0.5825; F1: 0.3523
# N: 4884
# seq_length: 30
# Comb-logits-based-Epoch: 44; tao=0.7; Accu: 48.89; Pre: 0.07588; Rec: 0.07479; F1: 0.07534
# N: 3617
# seq_length: 30
# Comb-statistic-based-Epoch: 44; tao=0.7; Accu: 36.21; Pre: 0.2479; Rec: 0.635; F1: 0.3566
# seq_length: 30
# sample-wise-Epoch: 44; tao=0.7; Accu: 36.41; Pre: 0.263; Rec: 0.6296; F1: 0.371
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 7021
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.2; Accu: 70.28; Pre: 0.3691; Rec: 0.09529; F1: 0.1515
# N: 6266
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.2; Accu: 62.72; Pre: 0.1107; Rec: 0.04818; F1: 0.06713
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.2; Accu: 69.21; Pre: 0.381; Rec: 0.05387; F1: 0.0944
# N: 6413
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.3; Accu: 64.19; Pre: 0.2801; Rec: 0.1823; F1: 0.2209
# N: 6091
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.3; Accu: 60.97; Pre: 0.3296; Rec: 0.3887; F1: 0.3567
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.3; Accu: 59.78; Pre: 0.3405; Rec: 0.3737; F1: 0.3563
# N: 6197
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.4; Accu: 62.03; Pre: 0.331; Rec: 0.3563; F1: 0.3432
# N: 5639
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.4; Accu: 56.45; Pre: 0.3171; Rec: 0.4894; F1: 0.3848
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.4; Accu: 56.57; Pre: 0.33; Rec: 0.4444; F1: 0.3788
# N: 5820
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.5; Accu: 58.26; Pre: 0.3281; Rec: 0.4764; F1: 0.3886
# N: 4725
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.5; Accu: 47.3; Pre: 0.3169; Rec: 0.7727; F1: 0.4494
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.5; Accu: 47.94; Pre: 0.3358; Rec: 0.7643; F1: 0.4666
# N: 5407
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.6; Accu: 54.12; Pre: 0.304; Rec: 0.5027; F1: 0.3789
# N: 4480
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.6; Accu: 44.84; Pre: 0.3195; Rec: 0.8684; F1: 0.4671
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.6; Accu: 46.64; Pre: 0.3431; Rec: 0.8653; F1: 0.4914
# N: 5110
# seq_length: 30
# Comb-logits-based-Epoch: 45; tao=0.7; Accu: 51.15; Pre: 0.2904; Rec: 0.5228; F1: 0.3734
# N: 3446
# seq_length: 30
# Comb-statistic-based-Epoch: 45; tao=0.7; Accu: 34.49; Pre: 0.2908; Rec: 0.9407; F1: 0.4443
# seq_length: 30
# sample-wise-Epoch: 45; tao=0.7; Accu: 36.51; Pre: 0.3121; Rec: 0.9394; F1: 0.4685
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 6260
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.2; Accu: 62.66; Pre: 0.3464; Rec: 0.3848; F1: 0.3646
# N: 5167
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.2; Accu: 51.72; Pre: 0.1494; Rec: 0.1564; F1: 0.1528
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.2; Accu: 51.96; Pre: 0.184; Rec: 0.1785; F1: 0.1812
# N: 6121
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.3; Accu: 61.27; Pre: 0.342; Rec: 0.4236; F1: 0.3785
# N: 4358
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.3; Accu: 43.62; Pre: 0.165; Rec: 0.2524; F1: 0.1995
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.3; Accu: 43.43; Pre: 0.1829; Rec: 0.2593; F1: 0.2145
# N: 5912
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.4; Accu: 59.18; Pre: 0.3332; Rec: 0.466; F1: 0.3886
# N: 4425
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.4; Accu: 44.29; Pre: 0.1858; Rec: 0.2959; F1: 0.2283
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.4; Accu: 44.13; Pre: 0.2032; Rec: 0.2997; F1: 0.2422
# N: 5935
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.5; Accu: 59.41; Pre: 0.3414; Rec: 0.493; F1: 0.4034
# N: 4293
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.5; Accu: 42.97; Pre: 0.2116; Rec: 0.3848; F1: 0.2731
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.5; Accu: 43.13; Pre: 0.2321; Rec: 0.3939; F1: 0.2921
# N: 5979
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.6; Accu: 59.85; Pre: 0.3495; Rec: 0.5135; F1: 0.4159
# N: 3138
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.6; Accu: 31.41; Pre: 0.2561; Rec: 0.7688; F1: 0.3843
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.6; Accu: 32.5; Pre: 0.2751; Rec: 0.7744; F1: 0.406
# N: 5944
# seq_length: 30
# Comb-logits-based-Epoch: 46; tao=0.7; Accu: 59.5; Pre: 0.3506; Rec: 0.534; F1: 0.4233
# N: 3078
# seq_length: 30
# Comb-statistic-based-Epoch: 46; tao=0.7; Accu: 30.81; Pre: 0.2671; Rec: 0.8515; F1: 0.4066
# seq_length: 30
# sample-wise-Epoch: 46; tao=0.7; Accu: 33.2; Pre: 0.2992; Rec: 0.9259; F1: 0.4523
# sample_shape: 997
# num_samples_t 997
# /home/zvd0712/Documents/MAD-GAN-DDoS/DR_discriminator.py:604: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(num_units=hidden_units_d, state_is_tuple=True, reuse=reuse)
# N: 8057
# seq_length: 30
# Comb-logits-based-Epoch: 47; tao=0.2; Accu: 80.65; Pre: 0.8068; Rec: 0.4009; F1: 0.5357
# N: 5998
# seq_length: 30
# Comb-statistic-based-Epoch: 47; tao=0.2; Accu: 60.04; Pre: 0.05964; Rec: 0.02949; F1: 0.03946
# seq_length: 30
# sample-wise-Epoch: 47; tao=0.2; Accu: 57.97; Pre: 0.04478; Rec: 0.0202; F1: 0.02784
# N: 7949
# seq_length: 30
# Comb-logits-based-Epoch: 47; tao=0.3; Accu: 79.57; Pre: 0.6591; Rec: 0.5512; F1: 0.6004
# N: 5885
# seq_length: 30
# Comb-statistic-based-Epoch: 47; tao=0.3; Accu: 58.91; Pre: 0.2305; Rec: 0.2035; F1: 0.2162
# seq_length: 30
# sample-wise-Epoch: 47; tao=0.3; Accu: 58.88; Pre: 0.2694; Rec: 0.2222; F1: 0.2435
# N: 7367
# seq_length: 30
# Comb-logits-based-Epoch: 47; tao=0.4; Accu: 73.74; Pre: 0.5254; Rec: 0.5872; F1: 0.5546
# N: 4242
# seq_length: 30
# Comb-statistic-based-Epoch: 47; tao=0.4; Accu: 42.46; Pre: 0.1472; Rec: 0.2226; F1: 0.1772
# seq_length: 30
# sample-wise-Epoch: 47; tao=0.4; Accu: 42.23; Pre: 0.1686; Rec: 0.2391; F1: 0.1978
# N: 6231
# seq_length: 30
# Comb-logits-based-Epoch: 47; tao=0.5; Accu: 62.37; Pre: 0.3865; Rec: 0.5987; F1: 0.4697
# N: 4891
# seq_length: 30
# Comb-statistic-based-Epoch: 47; tao=0.5; Accu: 48.96; Pre: 0.3121; Rec: 0.6922; F1: 0.4302
# seq_length: 30
# sample-wise-Epoch: 47; tao=0.5; Accu: 50.85; Pre: 0.3451; Rec: 0.7239; F1: 0.4674
# N: 5736
# seq_length: 30
# Comb-logits-based-Epoch: 47; tao=0.6; Accu: 57.42; Pre: 0.3482; Rec: 0.6073; F1: 0.4426
# N: 4361
# seq_length: 30
# Comb-statistic-based-Epoch: 47; tao=0.6; Accu: 43.65; Pre: 0.3075; Rec: 0.8181; F1: 0.447
# seq_length: 30
# sample-wise-Epoch: 47; tao=0.6; Accu: 47.94; Pre: 0.3428; Rec: 0.8148; F1: 0.4826

# %%
end = time.time()
print(end-start)
