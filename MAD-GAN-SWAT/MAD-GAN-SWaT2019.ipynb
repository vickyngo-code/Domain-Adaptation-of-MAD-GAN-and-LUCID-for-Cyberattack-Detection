# %%
import numpy
a = numpy.load('./experiments/plots/Results_swat_30.npy')
print(a)
numpy.savetxt("./experiments/plots/Results_swat_30.csv", a, delimiter=",")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6c596071ea32> in <module>
# ----> 1 import numpy
#       2 a = numpy.load('./experiments/plots/Results_swat_30.npy')
#       3 print(a)
#       4 numpy.savetxt("./experiments/plots/Results_swat_30.csv", a, delimiter=",")
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/zvd0712/miniconda3/envs/python36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-4b6fefb1997e>", line 1, in <module>
#     import tensorflow as tf
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow/__init__.py", line 99, in <module>
#     from tensorflow_core import *
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 28, in <module>
#     from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
# ...

# %%
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.Session(config=config)

# %%
# !pip install scipy
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = "-1"

# %%
# !python3 RGAN.py --settings_file swat
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/swat.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded swat from .csv
# (405254, 79)
# num_samples: 38362
# num_signals: 6
# Generated/loaded 38362 samples from data-type swat
# samples_size: (38362, 30, 6)
# num_variables: 6
# Ready to run with settings:
#  	 settings_file
# swat 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# ...

# %%
# !python3 AD.py --settings_file swat_test
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/swat_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded swat_a from .csv
# (460623, 77)
# Generated/loaded 46059 samples from data-type swat_test
# Ready to run with settings:
#  	 settings_file
# swat_test 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# ...

# %%
# !python3 AD_Invert.py --settings_file swat_test
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/swat_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded swat_a from .csv
# (460623, 79)
# Generated/loaded 46059 samples from data-type swat_test
# Ready to run with settings:
#  	 settings_file
# swat_test 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# ...

# %%
# !python3 RGAN.py --settings_file cicddos

# %%
# !python3 AD.py --settings_file cicddos_test
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/cicddos_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# Loaded CICDDoS2019 from .csv
# (388769, 79)
# Generated/loaded 38873 samples from data-type cicddos2019
# Ready to run with settings:
#  	 settings_file
# cicddos2019 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# ...

# %%
# !python3 RGAN.py --settings_file kdd99
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/kdd99.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# load kdd99_train from .npy
# Generated/loaded 56235 samples from data-type kdd99
# samples_size: (56235, 30, 6)
# num_variables: 6
# Ready to run with settings:
#  	 settings_file
# kdd99 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# ...

# %%
# !python3 AD.py --settings_file kdd99_test
# Out:
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
#
# WARNING:tensorflow:From /home/zvd0712/Documents/MAD-GANs-SWaT2019/model.py:11: The name tf.logging.ERROR is deprecated. Please use tf.compat.v1.logging.ERROR instead.
#
# Using TensorFlow backend.
# Loading settings from ./experiments/settings/kdd99_test.txt
# Loading data from ./experiments/data/.data.npy
# data_type
# load kdd99_test from .npy
# Generated/loaded 49399 samples from data-type kdd99_test
# Ready to run with settings:
#  	 settings_file
# kdd99_test 	 data
# 30 	 seq_length
# 6 	 num_signals
# False 	 normalise
# 0.1 	 scale
# 1.0 	 freq_low
# 5.0 	 freq_high
# 0.1 	 amplitude_low
# 0.9 	 amplitude_high
# False 	 multivariate_mnist
# False 	 full_mnist
#  	 data_load_from
# 15 	 resample_rate_in_min
# 100 	 hidden_units_g
# 100 	 hidden_units_d
# 100 	 hidden_units_e
# 1 	 kappa
# ...

# %%
# !python3 AD_Invert.py --settings_file kdd99_test
# Out:
# Traceback (most recent call last):
#   File "AD_Invert.py", line 1, in <module>
#     import tensorflow as tf
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow/__init__.py", line 99, in <module>
#     from tensorflow_core import *
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow_core/__init__.py", line 28, in <module>
#     from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/home/zvd0712/.local/lib/python3.6/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/home/zvd0712/miniconda3/envs/python36/lib/python3.6/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ...
